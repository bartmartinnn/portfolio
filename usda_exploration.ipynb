# %% [markdown]
# <a href="https://colab.research.google.com/github/bartoszlibner/usda/blob/main/usda_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os

# %%
# !pip install PyDrive
# Out:
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.7/dist-packages (1.3.1)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.7/dist-packages (from PyDrive) (1.12.8)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.7/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: six<2dev,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.15.0)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.26.3)
# Requirement already satisfied: google-auth>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.35.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.0.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.17.4)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (2.23.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (2018.9)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (1.53.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (21.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (57.4.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (3.17.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client>=1.2->PyDrive) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client>=1.2->PyDrive) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client>=1.2->PyDrive) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.8)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (1.24.3)

# %%
pd.set_option('max_rows', 99999)
pd.set_option('max_colwidth', 400)

# %% [markdown]
# Next cell contains libraries required to authenticate to GoogleDrive. In GoogleDrive a database in excel sheet form of all the USDA ingredients

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded_foundation_food = drive.CreateFile({'id':"1qBqmL9i9ff9UL5n2Tp8oWYE1XDiHRYE0"})   
downloaded_foundation_food.GetContentFile('foundation_food.csv')        

downloaded_sr_legacy = drive.CreateFile({'id':"1sqhYFFxdR-uannIidxkIjj9RqMbjempe"})   
downloaded_sr_legacy.GetContentFile('sr_legacy_food.csv')        

downloaded_sr_legacy = drive.CreateFile({'id':"122upIOEuxK0rtciVyzCk7WEIBx4UBW5v"})   
downloaded_sr_legacy.GetContentFile('sr_legacy_food_portions.csv')        

downloaded_sr_legacy = drive.CreateFile({'id':"1iG2rZ1U2_Rgma6ex6ZqsK0VZh_5HPsKt"})   
downloaded_sr_legacy.GetContentFile('sr_legacy_food_nutrient.csv')        


downloaded_sr_legacy = drive.CreateFile({'id':"1G1nUfAtMNcJuSFRHtun2ZMoFX5q9HXsc"})   
downloaded_sr_legacy.GetContentFile('nutrient.csv')

# %%
data = pd.read_csv('foundation_food.csv')
sr_legacy_data = pd.read_csv('sr_legacy_food.csv')
sr_legacy_data_portions = pd.read_csv('sr_legacy_food_portions.csv')
sr_legacy_data_nutrients = pd.read_csv('sr_legacy_food_nutrient.csv')
df_nutrient_descriptions = pd.read_csv('nutrient.csv')

# %%
df = data.copy()

# %% [markdown]
# There are differences between what USDA is saying in their "Download field description file" and what we actually have in this table. There should be couple of fields more that should have more data, but we can still work with it IMO

# %% [markdown]
# # exploring the amount of unique data types and numbers connexted to them

# %%
df['data_type'].unique()
# Out:
# array(['sample_food', 'market_acquisition', 'sub_sample_food',
#        'foundation_food', 'agricultural_acquisition'], dtype=object)

# %%
mark_safo_noduplicates = df[df['data_type'] == 'sample_food'].drop_duplicates(subset='description')
mark_safo_noduplicates
# Out:
#         fdc_id    data_type  ... food_category_id  publication_date
# 0       319874  sample_food  ...             16.0        2019-04-01
# 20      319894  sample_food  ...             16.0        2019-04-01
# 84      319958  sample_food  ...             16.0        2019-04-01
# 150     320025  sample_food  ...              1.0        2019-04-01
# 477     320353  sample_food  ...             13.0        2019-04-01
# 481     320357  sample_food  ...             13.0        2019-04-01
# 506     320382  sample_food  ...             13.0        2019-04-01
# 508     320384  sample_food  ...             13.0        2019-04-01
# 512     320388  sample_food  ...             13.0        2019-04-01
# 514     320390  sample_food  ...             13.0        2019-04-01
# 516     320392  sample_food  ...             13.0        2019-04-01
# 518     320394  sample_food  ...             13.0        2019-04-01
# 520     320396  sample_food  ...             13.0        2019-04-01
# 524     320400  sample_food  ...             13.0        2019-04-01
# 526     320402  sample_food  ...             13.0        2019-04-01
# 528     320404  sample_food  ...             13.0        2019-04-01
# 530     320406  sample_food  ...             13.0        2019-04-01
# 532     320408  sample_food  ...             13.0        2019-04-01
# 534     320410  sample_food  ...             13.0        2019-04-01
# 536     320413  sample_food  ...             11.0        2019-04-01
# 654     321361  sample_food  ...              2.0        2019-04-01
# 666     321373  sample_food  ...              2.0        2019-04-01
# 672     321379  sample_food  ...              2.0        2019-04-01
# 699     321406  sample_food  ...              2.0        2019-04-01
# 705     321412  sample_food  ...              2.0        2019-04-01
# 722     321429  sample_food  ...              2.0        2019-04-01
# 751     321458  sample_food  ...              2.0        2019-04-01
# 757     321464  sample_food  ...              2.0        2019-04-01
# 768     321475  sample_food  ...              2.0        2019-04-01
# 799     321506  sample_food  ...             11.0        2019-04-01
# 850     321557  sample_food  ...             11.0        2019-04-01
# 884     321591  sample_food  ...             11.0        2019-04-01
# 905     321612  sample_food  ...             11.0        2019-04-01
# 911     321618  sample_food  ...             11.0        2019-04-01
# 914     321621  sample_food  ...             11.0        2019-04-01
# 921     321628  sample_food  ...             11.0        2019-04-01
# 924     321631  sample_food  ...             11.0        2019-04-01
# 931     321638  sample_food  ...             11.0        2019-04-01
# 934     321641  sample_food  ...             11.0        2019-04-01
# 941     321648  sample_food  ...             11.0        2019-04-01
# 944     321651  sample_food  ...             11.0        2019-04-01
# 967     321674  sample_food  ...             11.0        2019-04-01
# 986     321693  sample_food  ...             11.0        2019-04-01
# 1011    321718  sample_food  ...             11.0        2019-04-01
# 1039    321746  sample_food  ...             11.0        2019-04-01
# 1056    321763  sample_food  ...             11.0        2019-04-01
# 1084    321791  sample_food  ...             11.0        2019-04-01
# 1103    321810  sample_food  ...             11.0        2019-04-01
# 1122    321829  sample_food  ...             11.0        2019-04-01
# 1138    321845  sample_food  ...             11.0        2019-04-01
# 1156    321863  sample_food  ...             11.0        2019-04-01
# 1173    321880  sample_food  ...             11.0        2019-04-01
# 1194    321901  sample_food  ...              1.0        2019-04-01
# 1313    322020  sample_food  ...              1.0        2019-04-01
# 1522    322229  sample_food  ...              1.0        2019-04-01
# 1853    322560  sample_food  ...              1.0        2019-04-01
# 2186    322893  sample_food  ...              7.0        2019-04-01
# 2248    322955  sample_food  ...              7.0        2019-04-01
# 2337    323044  sample_food  ...              7.0        2019-04-01
# 2415    323122  sample_food  ...             12.0        2019-04-01
# 2471    323178  sample_food  ...             12.0        2019-04-01
# 2498    323205  sample_food  ...             12.0        2019-04-01
# 2558    323265  sample_food  ...             12.0        2019-04-01
# 2573    323280  sample_food  ...             12.0        2019-04-01
# 2588    323295  sample_food  ...              1.0        2019-04-01
# 2597    323304  sample_food  ...              1.0        2019-04-01
# 2635    323342  sample_food  ...              1.0        2019-04-01
# 2654    323361  sample_food  ...              1.0        2019-04-01
# 2671    323378  sample_food  ...              1.0        2019-04-01
# 2738    323445  sample_food  ...             11.0        2019-04-01
# 2799    323506  sample_food  ...              1.0        2019-04-01
# 2806    323513  sample_food  ...              1.0        2019-04-01
# 2841    323548  sample_food  ...              1.0        2019-04-01
# 2855    323562  sample_food  ...              1.0        2019-04-01
# 2862    323569  sample_food  ...              1.0        2019-04-01
# 2898    323605  sample_food  ...              1.0        2019-04-01
# 2915    323622  sample_food  ...              1.0        2019-04-01
# 2920    323627  sample_food  ...              1.0        2019-04-01
# 2939    323646  sample_food  ...              1.0        2019-04-01
# 2956    323663  sample_food  ...              1.0        2019-04-01
# 2967    323674  sample_food  ...              1.0        2019-04-01
# 2991    323698  sample_food  ...              1.0        2019-04-01
# 2998    323705  sample_food  ...              1.0        2019-04-01
# 3029    323736  sample_food  ...              1.0        2019-04-01
# 3041    323748  sample_food  ...              1.0        2019-04-01
# 3067    323774  sample_food  ...              1.0        2019-04-01
# 3087    323794  sample_food  ...              6.0        2019-04-01
# 3134    323841  sample_food  ...              6.0        2019-04-01
# 3180    323887  sample_food  ...              6.0        2019-04-01
# 3189    323896  sample_food  ...              6.0        2019-04-01
# 3198    323905  sample_food  ...              6.0        2019-04-01
# 3207    323914  sample_food  ...              6.0        2019-04-01
# 3224    323931  sample_food  ...              6.0        2019-04-01
# 3240    323947  sample_food  ...              6.0        2019-04-01
# 3256    323963  sample_food  ...              6.0        2019-04-01
# 3265    323972  sample_food  ...              6.0        2019-04-01
# 3281    323988  sample_food  ...              6.0        2019-04-01
# 3296    324003  sample_food  ...              6.0        2019-04-01
# 3305    324012  sample_food  ...              6.0        2019-04-01
# 3314    324021  sample_food  ...              6.0        2019-04-01
# 3332    324039  sample_food  ...              7.0        2019-04-01
# 3346    324053  sample_food  ...              7.0        2019-04-01
# 3428    324135  sample_food  ...              7.0        2019-04-01
# 3451    324158  sample_food  ...             11.0        2019-04-01
# 3458    324165  sample_food  ...             11.0        2019-04-01
# 3463    324170  sample_food  ...             11.0        2019-04-01
# 3470    324177  sample_food  ...             11.0        2019-04-01
# 3488    324195  sample_food  ...             11.0        2019-04-01
# 3507    324214  sample_food  ...             11.0        2019-04-01
# 3526    324233  sample_food  ...             11.0        2019-04-01
# 3545    324252  sample_food  ...             11.0        2019-04-01
# 3552    324259  sample_food  ...             11.0        2019-04-01
# 3571    324278  sample_food  ...             11.0        2019-04-01
# 3590    324297  sample_food  ...             11.0        2019-04-01
# 3611    324318  sample_food  ...             11.0        2019-04-01
# 3618    324325  sample_food  ...             11.0        2019-04-01
# 3625    324332  sample_food  ...             11.0        2019-04-01
# 3632    324339  sample_food  ...             11.0        2019-04-01
# 3645    324352  sample_food  ...             11.0        2019-04-01
# 3652    324359  sample_food  ...             11.0        2019-04-01
# 3659    324366  sample_food  ...             11.0        2019-04-01
# 3676    324383  sample_food  ...             11.0        2019-04-01
# 3694    324401  sample_food  ...             11.0        2019-04-01
# 3707    324414  sample_food  ...             11.0        2019-04-01
# 3714    324421  sample_food  ...             11.0        2019-04-01
# 3731    324438  sample_food  ...             11.0        2019-04-01
# 3738    324445  sample_food  ...             11.0        2019-04-01
# 3745    324452  sample_food  ...             11.0        2019-04-01
# 3752    324459  sample_food  ...             11.0        2019-04-01
# 3765    324472  sample_food  ...             11.0        2019-04-01
# 3778    324485  sample_food  ...             11.0        2019-04-01
# 3795    324502  sample_food  ...             11.0        2019-04-01
# 3807    324514  sample_food  ...             11.0        2019-04-01
# 3854    324561  sample_food  ...             11.0        2019-04-01
# 3891    324598  sample_food  ...             11.0        2019-04-01
# 3938    324645  sample_food  ...             11.0        2019-04-01
# 3947    324654  sample_food  ...             16.0        2019-04-01
# 3954    324661  sample_food  ...             16.0        2019-04-01
# 3961    324668  sample_food  ...             16.0        2019-04-01
# 3976    324683  sample_food  ...             16.0        2019-04-01
# 3982    324689  sample_food  ...             16.0        2019-04-01
# 4003    324710  sample_food  ...             16.0        2019-04-01
# 4019    324726  sample_food  ...             16.0        2019-04-01
# 4025    324732  sample_food  ...             16.0        2019-04-01
# 4041    324748  sample_food  ...             16.0        2019-04-01
# 4047    324754  sample_food  ...             16.0        2019-04-01
# 4053    324760  sample_food  ...             16.0        2019-04-01
# 4059    324766  sample_food  ...             16.0        2019-04-01
# 4074    324781  sample_food  ...             16.0        2019-04-01
# 4091    324798  sample_food  ...             16.0        2019-04-01
# 4098    324805  sample_food  ...             16.0        2019-04-01
# 4115    324822  sample_food  ...             16.0        2019-04-01
# 4131    324838  sample_food  ...             16.0        2019-04-01
# 4146    324853  sample_food  ...             16.0        2019-04-01
# 4154    324861  sample_food  ...              1.0        2019-04-01
# 4164    324871  sample_food  ...              1.0        2019-04-01
# 4174    324881  sample_food  ...              1.0        2019-04-01
# 4184    324891  sample_food  ...              1.0        2019-04-01
# 4206    324913  sample_food  ...              1.0        2019-04-01
# 4214    324921  sample_food  ...              1.0        2019-04-01
# 4233    324940  sample_food  ...              1.0        2019-04-01
# 4253    324960  sample_food  ...              1.0        2019-04-01
# 4263    324970  sample_food  ...              1.0        2019-04-01
# 4282    324989  sample_food  ...              1.0        2019-04-01
# 4300    325007  sample_food  ...              1.0        2019-04-01
# 4310    325017  sample_food  ...              1.0        2019-04-01
# 4330    325037  sample_food  ...              1.0        2019-04-01
# 4339    325046  sample_food  ...              1.0        2019-04-01
# 4354    325061  sample_food  ...              1.0        2019-04-01
# 4368    325075  sample_food  ...              1.0        2019-04-01
# 4389    325096  sample_food  ...              1.0        2019-04-01
# 4394    325101  sample_food  ...              1.0        2019-04-01
# 4400    325107  sample_food  ...              1.0        2019-04-01
# 4407    325114  sample_food  ...              1.0        2019-04-01
# 4412    325119  sample_food  ...              1.0        2019-04-01
# 4422    325129  sample_food  ...              1.0        2019-04-01
# 4426    325133  sample_food  ...              1.0        2019-04-01
# 4431    325138  sample_food  ...              1.0        2019-04-01
# 4441    325148  sample_food  ...              1.0        2019-04-01
# 4446    325153  sample_food  ...              1.0        2019-04-01
# 4450    325157  sample_food  ...              1.0        2019-04-01
# 4454    325161  sample_food  ...              1.0        2019-04-01
# 4457    325164  sample_food  ...              1.0        2019-04-01
# 4462    325169  sample_food  ...              1.0        2019-04-01
# 4466    325173  sample_food  ...              1.0        2019-04-01
# 4470    325177  sample_food  ...              1.0        2019-04-01
# 4474    325181  sample_food  ...              1.0        2019-04-01
# 4479    325186  sample_food  ...              1.0        2019-04-01
# 4483    325190  sample_food  ...              1.0        2019-04-01
# 4487    325194  sample_food  ...              1.0        2019-04-01
# 4492    325199  sample_food  ...              9.0        2019-04-01
# 4512    325219  sample_food  ...              9.0        2019-04-01
# 4556    325263  sample_food  ...              9.0        2019-04-01
# 4581    325288  sample_food  ...              9.0        2019-04-01
# 4598    325305  sample_food  ...              9.0        2019-04-01
# 4616    325323  sample_food  ...              9.0        2019-04-01
# 4634    325341  sample_food  ...              9.0        2019-04-01
# 4653    325360  sample_food  ...              9.0        2019-04-01
# 4671    325378  sample_food  ...              9.0        2019-04-01
# 4689    325396  sample_food  ...              9.0        2019-04-01
# 4706    325413  sample_food  ...              9.0        2019-04-01
# 4724    325431  sample_food  ...             12.0        2019-04-01
# 4732    325439  sample_food  ...             12.0        2019-04-01
# 4818    325525  sample_food  ...              7.0        2019-04-01
# 4842    325549  sample_food  ...              7.0        2019-04-01
# 4865    325572  sample_food  ...              7.0        2019-04-01
# 4873    325580  sample_food  ...              7.0        2019-04-01
# 4891    325598  sample_food  ...              7.0        2019-04-01
# 4952    325659  sample_food  ...             18.0        2019-04-01
# 4962    325669  sample_food  ...             18.0        2019-04-01
# 4972    325679  sample_food  ...             18.0        2019-04-01
# 4982    325689  sample_food  ...             18.0        2019-04-01
# 4991    325698  sample_food  ...             18.0        2019-04-01
# 5001    325708  sample_food  ...             18.0        2019-04-01
# 5011    325718  sample_food  ...             18.0        2019-04-01
# 5018    325725  sample_food  ...             18.0        2019-04-01
# 5025    325732  sample_food  ...             18.0        2019-04-01
# 5032    325739  sample_food  ...             18.0        2019-04-01
# 5039    325746  sample_food  ...             18.0        2019-04-01
# 5046    325753  sample_food  ...             18.0        2019-04-01
# 5053    325760  sample_food  ...             18.0        2019-04-01
# 5060    325767  sample_food  ...             18.0        2019-04-01
# 5067    325774  sample_food  ...             18.0        2019-04-01
# 5074    325781  sample_food  ...             18.0        2019-04-01
# 5081    325788  sample_food  ...             18.0        2019-04-01
# 5088    325795  sample_food  ...             18.0        2019-04-01
# 5103    325810  sample_food  ...             18.0        2019-04-01
# 5118    325825  sample_food  ...             18.0        2019-04-01
# 5134    325841  sample_food  ...             18.0        2019-04-01
# 5149    325856  sample_food  ...             18.0        2019-04-01
# 5165    325872  sample_food  ...              7.0        2019-04-01
# 5174    325881  sample_food  ...              7.0        2019-04-01
# 5184    325891  sample_food  ...              7.0        2019-04-01
# 5222    325929  sample_food  ...              7.0        2019-04-01
# 5241    325948  sample_food  ...              7.0        2019-04-01
# 5249    325956  sample_food  ...              7.0        2019-04-01
# 5286    325993  sample_food  ...              1.0        2019-04-01
# 5291    325998  sample_food  ...              1.0        2019-04-01
# 5297    326004  sample_food  ...              1.0        2019-04-01
# 5303    326010  sample_food  ...              1.0        2019-04-01
# 5317    326024  sample_food  ...              1.0        2019-04-01
# 5323    326030  sample_food  ...              1.0        2019-04-01
# 5344    326051  sample_food  ...              1.0        2019-04-01
# 5350    326057  sample_food  ...              1.0        2019-04-01
# 5369    326076  sample_food  ...              1.0        2019-04-01
# 5375    326082  sample_food  ...              1.0        2019-04-01
# 5393    326100  sample_food  ...              1.0        2019-04-01
# 5407    326114  sample_food  ...              1.0        2019-04-01
# 5429    326136  sample_food  ...             11.0        2019-04-01
# 5490    326197  sample_food  ...             11.0        2019-04-01
# 5510    326217  sample_food  ...             11.0        2019-04-01
# 5530    326237  sample_food  ...             11.0        2019-04-01
# 5558    326265  sample_food  ...             11.0        2019-04-01
# 5578    326285  sample_food  ...             11.0        2019-04-01
# 5607    326314  sample_food  ...             11.0        2019-04-01
# 5626    326333  sample_food  ...             11.0        2019-04-01
# 5644    326351  sample_food  ...             11.0        2019-04-01
# 5673    326380  sample_food  ...             11.0        2019-04-01
# 5692    326399  sample_food  ...             11.0        2019-04-01
# 5720    326427  sample_food  ...             11.0        2019-04-01
# 5752    326459  sample_food  ...              2.0        2019-04-01
# 5759    326466  sample_food  ...              2.0        2019-04-01
# 5766    326473  sample_food  ...              2.0        2019-04-01
# 5773    326480  sample_food  ...              2.0        2019-04-01
# 5780    326487  sample_food  ...              2.0        2019-04-01
# 5787    326494  sample_food  ...              2.0        2019-04-01
# 5803    326510  sample_food  ...              2.0        2019-04-01
# 5822    326529  sample_food  ...              2.0        2019-04-01
# 5830    326537  sample_food  ...              2.0        2019-04-01
# 5851    326558  sample_food  ...              2.0        2019-04-01
# 5865    326572  sample_food  ...              2.0        2019-04-01
# 5884    326591  sample_food  ...              2.0        2019-04-01
# 5898    326605  sample_food  ...              2.0        2019-04-01
# 5929    326636  sample_food  ...              2.0        2019-04-01
# 5960    326667  sample_food  ...              2.0        2019-04-01
# 5992    326699  sample_food  ...              9.0        2019-04-01
# 6017    326724  sample_food  ...              9.0        2019-04-01
# 6042    326749  sample_food  ...              9.0        2019-04-01
# 6073    326780  sample_food  ...              9.0        2019-04-01
# 6099    326806  sample_food  ...              9.0        2019-04-01
# 6125    326832  sample_food  ...              9.0        2019-04-01
# 6147    326854  sample_food  ...              9.0        2019-04-01
# 6173    326880  sample_food  ...              9.0        2019-04-01
# 6199    326906  sample_food  ...              9.0        2019-04-01
# 6211    326918  sample_food  ...              9.0        2019-04-01
# 6231    326938  sample_food  ...              9.0        2019-04-01
# 6252    326959  sample_food  ...              9.0        2019-04-01
# 6271    326978  sample_food  ...              9.0        2019-04-01
# 6292    326999  sample_food  ...              9.0        2019-04-01
# 6312    327019  sample_food  ...              9.0        2019-04-01
# 6323    327030  sample_food  ...              9.0        2019-04-01
# 6340    327047  sample_food  ...              9.0        2019-04-01
# 6358    327065  sample_food  ...              9.0        2019-04-01
# 6378    327085  sample_food  ...              9.0        2019-04-01
# 6398    327105  sample_food  ...              9.0        2019-04-01
# 6417    327124  sample_food  ...              9.0        2019-04-01
# 6435    327142  sample_food  ...              9.0        2019-04-01
# 6453    327160  sample_food  ...              9.0        2019-04-01
# 6472    327179  sample_food  ...              9.0        2019-04-01
# 6492    327199  sample_food  ...              9.0        2019-04-01
# 6510    327217  sample_food  ...              9.0        2019-04-01
# 6529    327236  sample_food  ...              9.0        2019-04-01
# 6551    327258  sample_food  ...              9.0        2019-04-01
# 6571    327278  sample_food  ...              9.0        2019-04-01
# 6591    327298  sample_food  ...              9.0        2019-04-01
# 6610    327317  sample_food  ...              9.0        2019-04-01
# 6629    327336  sample_food  ...              9.0        2019-04-01
# 6651    327358  sample_food  ...              9.0        2019-04-01
# 6667    327374  sample_food  ...              9.0        2019-04-01
# 6684    327391  sample_food  ...              9.0        2019-04-01
# 6701    327408  sample_food  ...              9.0        2019-04-01
# 6721    327428  sample_food  ...              9.0        2019-04-01
# 6741    327448  sample_food  ...              9.0        2019-04-01
# 6759    327466  sample_food  ...              9.0        2019-04-01
# 6778    327485  sample_food  ...              9.0        2019-04-01
# 6795    327502  sample_food  ...              9.0        2019-04-01
# 6820    327527  sample_food  ...              9.0        2019-04-01
# 6845    327552  sample_food  ...              9.0        2019-04-01
# 6871    327578  sample_food  ...              9.0        2019-04-01
# 6895    327602  sample_food  ...              9.0        2019-04-01
# 6919    327626  sample_food  ...              9.0        2019-04-01
# 6945    327652  sample_food  ...              9.0        2019-04-01
# 6968    327675  sample_food  ...              9.0        2019-04-01
# 6993    327700  sample_food  ...             11.0        2019-04-01
# 6999    327706  sample_food  ...             11.0        2019-04-01
# 7006    327713  sample_food  ...             11.0        2019-04-01
# 7013    327720  sample_food  ...             11.0        2019-04-01
# 7021    327728  sample_food  ...             11.0        2019-04-01
# 7028    327735  sample_food  ...             11.0        2019-04-01
# 7035    327742  sample_food  ...             11.0        2019-04-01
# 7053    327760  sample_food  ...             11.0        2019-04-01
# 7074    327781  sample_food  ...             11.0        2019-04-01
# 7096    327803  sample_food  ...             11.0        2019-04-01
# 7119    327826  sample_food  ...             11.0        2019-04-01
# 7144    327851  sample_food  ...             11.0        2019-04-01
# 7168    327875  sample_food  ...             11.0        2019-04-01
# 7192    327899  sample_food  ...             11.0        2019-04-01
# 7217    327924  sample_food  ...              1.0        2019-04-01
# 7229    327936  sample_food  ...              1.0        2019-04-01
# 7241    327948  sample_food  ...              1.0        2019-04-01
# 7253    327960  sample_food  ...              1.0        2019-04-01
# 7273    327980  sample_food  ...              1.0        2019-04-01
# 7291    327998  sample_food  ...              1.0        2019-04-01
# 7301    328008  sample_food  ...              1.0        2019-04-01
# 7313    328020  sample_food  ...              1.0        2019-04-01
# 7338    328045  sample_food  ...              1.0        2019-04-01
# 7350    328057  sample_food  ...              1.0        2019-04-01
# 7363    328070  sample_food  ...              1.0        2019-04-01
# 7387    328094  sample_food  ...              1.0        2019-04-01
# 7407    328114  sample_food  ...              1.0        2019-04-01
# 7415    328122  sample_food  ...              1.0        2019-04-01
# 7423    328130  sample_food  ...              1.0        2019-04-01
# 7446    328153  sample_food  ...              1.0        2019-04-01
# 7468    328175  sample_food  ...              1.0        2019-04-01
# 7484    328191  sample_food  ...              1.0        2019-04-01
# 7501    328208  sample_food  ...              1.0        2019-04-01
# 7520    328227  sample_food  ...              1.0        2019-04-01
# 7541    328248  sample_food  ...              1.0        2019-04-01
# 7559    328266  sample_food  ...              1.0        2019-04-01
# 7579    328286  sample_food  ...              1.0        2019-04-01
# 7598    328305  sample_food  ...              1.0        2019-04-01
# 7619    328326  sample_food  ...              1.0        2019-04-01
# 7628    328335  sample_food  ...              1.0        2019-04-01
# 7637    328344  sample_food  ...              1.0        2019-04-01
# 7644    328351  sample_food  ...              1.0        2019-04-01
# 7651    328358  sample_food  ...              1.0        2019-04-01
# 7669    328376  sample_food  ...              1.0        2019-04-01
# 7687    328394  sample_food  ...              1.0        2019-04-01
# 7706    328413  sample_food  ...              1.0        2019-04-01
# 7725    328432  sample_food  ...              1.0        2019-04-01
# 7735    328442  sample_food  ...              1.0        2019-04-01
# 7747    328454  sample_food  ...              1.0        2019-04-01
# 7765    328472  sample_food  ...              1.0        2019-04-01
# 7783    328490  sample_food  ...              1.0        2019-04-01
# 7801    328508  sample_food  ...              1.0        2019-04-01
# 7822    328529  sample_food  ...              1.0        2019-04-01
# 7834    328541  sample_food  ...              1.0        2019-04-01
# 7842    328549  sample_food  ...              1.0        2019-04-01
# 7852    328559  sample_food  ...              1.0        2019-04-01
# 7860    328567  sample_food  ...              1.0        2019-04-01
# 7878    328585  sample_food  ...              1.0        2019-04-01
# 7887    328594  sample_food  ...              1.0        2019-04-01
# 7894    328601  sample_food  ...              1.0        2019-04-01
# 7913    328620  sample_food  ...              1.0        2019-04-01
# 7931    328638  sample_food  ...              1.0        2019-04-01
# 7939    328646  sample_food  ...              1.0        2019-04-01
# 7945    328652  sample_food  ...              1.0        2019-04-01
# 7953    328660  sample_food  ...              1.0        2019-04-01
# 7972    328679  sample_food  ...              1.0        2019-04-01
# 7988    328695  sample_food  ...              1.0        2019-04-01
# 8006    328713  sample_food  ...              1.0        2019-04-01
# 8014    328721  sample_food  ...              1.0        2019-04-01
# 8022    328729  sample_food  ...              1.0        2019-04-01
# 8029    328736  sample_food  ...              1.0        2019-04-01
# 8044    328751  sample_food  ...              1.0        2019-04-01
# 8062    328769  sample_food  ...              1.0        2019-04-01
# 8078    328785  sample_food  ...              1.0        2019-04-01
# 8086    328793  sample_food  ...              1.0        2019-04-01
# 8102    328809  sample_food  ...              1.0        2019-04-01
# 8117    328824  sample_food  ...              1.0        2019-04-01
# 8135    328842  sample_food  ...              1.0        2019-04-01
# 8143    328850  sample_food  ...              1.0        2019-04-01
# 8150    328857  sample_food  ...              1.0        2019-04-01
# 8162    328869  sample_food  ...              1.0        2019-04-01
# 8174    328881  sample_food  ...              1.0        2019-04-01
# 8195    328902  sample_food  ...              1.0        2019-04-01
# 8217    328924  sample_food  ...              1.0        2019-04-01
# 8239    328946  sample_food  ...              1.0        2019-04-01
# 8260    328967  sample_food  ...              1.0        2019-04-01
# 8268    328975  sample_food  ...              1.0        2019-04-01
# 8293    329000  sample_food  ...              1.0        2019-04-01
# 8305    329012  sample_food  ...              1.0        2019-04-01
# 8317    329024  sample_food  ...              1.0        2019-04-01
# 8329    329036  sample_food  ...              1.0        2019-04-01
# 8351    329058  sample_food  ...              1.0        2019-04-01
# 8368    329075  sample_food  ...              1.0        2019-04-01
# 8391    329098  sample_food  ...              1.0        2019-04-01
# 8412    329119  sample_food  ...              1.0        2019-04-01
# 8424    329131  sample_food  ...              1.0        2019-04-01
# 8431    329138  sample_food  ...              1.0        2019-04-01
# 8440    329147  sample_food  ...              1.0        2019-04-01
# 8453    329160  sample_food  ...              1.0        2019-04-01
# 8467    329174  sample_food  ...              1.0        2019-04-01
# 8482    329189  sample_food  ...              1.0        2019-04-01
# 8491    329198  sample_food  ...              1.0        2019-04-01
# 8509    329216  sample_food  ...              1.0        2019-04-01
# 8517    329224  sample_food  ...              1.0        2019-04-01
# 8525    329232  sample_food  ...              1.0        2019-04-01
# 8533    329240  sample_food  ...              1.0        2019-04-01
# 8548    329255  sample_food  ...              1.0        2019-04-01
# 8564    329271  sample_food  ...              1.0        2019-04-01
# 8572    329279  sample_food  ...              1.0        2019-04-01
# 8588    329295  sample_food  ...              1.0        2019-04-01
# 8602    329309  sample_food  ...              1.0        2019-04-01
# 8609    329316  sample_food  ...              1.0        2019-04-01
# 8624    329331  sample_food  ...              1.0        2019-04-01
# 8639    329346  sample_food  ...              1.0        2019-04-01
# 8652    329359  sample_food  ...              1.0        2019-04-01
# 8664    329371  sample_food  ...              1.0        2019-04-01
# 8671    329378  sample_food  ...              1.0        2019-04-01
# 8678    329385  sample_food  ...              1.0        2019-04-01
# 8692    329399  sample_food  ...              1.0        2019-04-01
# 8734    329441  sample_food  ...              1.0        2019-04-01
# 8769    329476  sample_food  ...              1.0        2019-04-01
# 8784    329491  sample_food  ...              1.0        2019-04-01
# 8798    329505  sample_food  ...              1.0        2019-04-01
# 8826    329533  sample_food  ...              1.0        2019-04-01
# 8833    329540  sample_food  ...              1.0        2019-04-01
# 8854    329561  sample_food  ...              1.0        2019-04-01
# 8890    329597  sample_food  ...              1.0        2019-04-01
# 8897    329604  sample_food  ...              1.0        2019-04-01
# 8911    329618  sample_food  ...              1.0        2019-04-01
# 8939    329646  sample_food  ...              1.0        2019-04-01
# 8946    329653  sample_food  ...              1.0        2019-04-01
# 8960    329667  sample_food  ...              1.0        2019-04-01
# 9010    329717  sample_food  ...              1.0        2019-04-01
# 9027    329734  sample_food  ...              1.0        2019-04-01
# 9044    329751  sample_food  ...              1.0        2019-04-01
# 9061    329768  sample_food  ...              1.0        2019-04-01
# 9076    329783  sample_food  ...              1.0        2019-04-01
# 9099    329806  sample_food  ...              1.0        2019-04-01
# 9124    329831  sample_food  ...              1.0        2019-04-01
# 9130    329837  sample_food  ...              1.0        2019-04-01
# 9139    329846  sample_food  ...              1.0        2019-04-01
# 9146    329853  sample_food  ...              1.0        2019-04-01
# 9163    329870  sample_food  ...              1.0        2019-04-01
# 9167    329874  sample_food  ...              1.0        2019-04-01
# 9176    329883  sample_food  ...              1.0        2019-04-01
# 9198    329905  sample_food  ...              1.0        2019-04-01
# 9226    329933  sample_food  ...              1.0        2019-04-01
# 9244    329951  sample_food  ...              1.0        2019-04-01
# 9266    329973  sample_food  ...              1.0        2019-04-01
# 9286    329993  sample_food  ...              1.0        2019-04-01
# 9301    330008  sample_food  ...              1.0        2019-04-01
# 9311    330018  sample_food  ...              1.0        2019-04-01
# 9328    330035  sample_food  ...              1.0        2019-04-01
# 9349    330056  sample_food  ...              1.0        2019-04-01
# 9372    330079  sample_food  ...              1.0        2019-04-01
# 9401    330108  sample_food  ...              1.0        2019-04-01
# 9431    330138  sample_food  ...              1.0        2019-04-01
# 9438    330145  sample_food  ...              1.0        2019-04-01
# 9445    330152  sample_food  ...              1.0        2019-04-01
# 9454    330161  sample_food  ...              1.0        2019-04-01
# 9471    330178  sample_food  ...              1.0        2019-04-01
# 9494    330201  sample_food  ...              1.0        2019-04-01
# 9514    330221  sample_food  ...              1.0        2019-04-01
# 9529    330236  sample_food  ...              1.0        2019-04-01
# 9550    330257  sample_food  ...              1.0        2019-04-01
# 9572    330279  sample_food  ...              1.0        2019-04-01
# 9585    330292  sample_food  ...              1.0        2019-04-01
# 9600    330307  sample_food  ...              1.0        2019-04-01
# 9622    330329  sample_food  ...              1.0        2019-04-01
# 9645    330352  sample_food  ...              1.0        2019-04-01
# 9669    330376  sample_food  ...              1.0        2019-04-01
# 9685    330392  sample_food  ...              1.0        2019-04-01
# 9709    330416  sample_food  ...              4.0        2019-04-01
# 9714    330421  sample_food  ...              4.0        2019-04-01
# 9719    330426  sample_food  ...              4.0        2019-04-01
# 9726    330433  sample_food  ...              4.0        2019-04-01
# 9734    330441  sample_food  ...              4.0        2019-04-01
# 9743    330450  sample_food  ...              4.0        2019-04-01
# 9752    330459  sample_food  ...              5.0        2019-04-01
# 9759    330466  sample_food  ...              5.0        2019-04-01
# 9779    330486  sample_food  ...              5.0        2019-04-01
# 9789    330496  sample_food  ...              5.0        2019-04-01
# 9793    330500  sample_food  ...              5.0        2019-04-01
# 9802    330509  sample_food  ...              5.0        2019-04-01
# 9812    330519  sample_food  ...              5.0        2019-04-01
# 9820    330527  sample_food  ...              5.0        2019-04-01
# 9829    330536  sample_food  ...              5.0        2019-04-01
# 9839    330546  sample_food  ...              5.0        2019-04-01
# 9852    330559  sample_food  ...              5.0        2019-04-01
# 9862    330569  sample_food  ...              5.0        2019-04-01
# 9866    330573  sample_food  ...              5.0        2019-04-01
# 9876    330583  sample_food  ...              5.0        2019-04-01
# 9883    330590  sample_food  ...              5.0        2019-04-01
# 9893    330600  sample_food  ...              5.0        2019-04-01
# 9903    330610  sample_food  ...              5.0        2019-04-01
# 9913    330620  sample_food  ...              5.0        2019-04-01
# 9917    330624  sample_food  ...              5.0        2019-04-01
# 9927    330634  sample_food  ...              5.0        2019-04-01
# 9934    330641  sample_food  ...              5.0        2019-04-01
# 9944    330651  sample_food  ...              5.0        2019-04-01
# 9955    330662  sample_food  ...              5.0        2019-04-01
# 9965    330672  sample_food  ...              5.0        2019-04-01
# 9969    330676  sample_food  ...              5.0        2019-04-01
# 9979    330686  sample_food  ...              5.0        2019-04-01
# 9988    330695  sample_food  ...              5.0        2019-04-01
# 9998    330705  sample_food  ...              5.0        2019-04-01
# 10012   330719  sample_food  ...              5.0        2019-04-01
# 10016   330723  sample_food  ...              5.0        2019-04-01
# 10023   330730  sample_food  ...              5.0        2019-04-01
# 10034   330741  sample_food  ...              5.0        2019-04-01
# 10038   330745  sample_food  ...              5.0        2019-04-01
# 10046   330753  sample_food  ...              5.0        2019-04-01
# 10059   330766  sample_food  ...              5.0        2019-04-01
# 10063   330770  sample_food  ...              5.0        2019-04-01
# 10071   330778  sample_food  ...              5.0        2019-04-01
# 10084   330791  sample_food  ...              5.0        2019-04-01
# 10088   330795  sample_food  ...              5.0        2019-04-01
# 10095   330802  sample_food  ...              5.0        2019-04-01
# 10106   330813  sample_food  ...              5.0        2019-04-01
# 10110   330817  sample_food  ...              5.0        2019-04-01
# 10117   330824  sample_food  ...              5.0        2019-04-01
# 10127   330834  sample_food  ...              5.0        2019-04-01
# 10131   330838  sample_food  ...              5.0        2019-04-01
# 10138   330845  sample_food  ...              5.0        2019-04-01
# 10149   330856  sample_food  ...              5.0        2019-04-01
# 10153   330860  sample_food  ...              5.0        2019-04-01
# 10163   330870  sample_food  ...              5.0        2019-04-01
# 10177   330884  sample_food  ...              5.0        2019-04-01
# 10203   330910  sample_food  ...              5.0        2019-04-01
# 10217   330924  sample_food  ...              5.0        2019-04-01
# 10225   330932  sample_food  ...              5.0        2019-04-01
# 10238   330945  sample_food  ...              5.0        2019-04-01
# 10246   330953  sample_food  ...              5.0        2019-04-01
# 10258   330965  sample_food  ...              5.0        2019-04-01
# 10317   331024  sample_food  ...              5.0        2019-04-01
# 10331   331038  sample_food  ...              5.0        2019-04-01
# 10388   331095  sample_food  ...              5.0        2019-04-01
# 10402   331109  sample_food  ...              5.0        2019-04-01
# 10459   331166  sample_food  ...              5.0        2019-04-01
# 10473   331180  sample_food  ...              5.0        2019-04-01
# 10527   331234  sample_food  ...              5.0        2019-04-01
# 10541   331248  sample_food  ...              5.0        2019-04-01
# 10593   331300  sample_food  ...              5.0        2019-04-01
# 10605   331312  sample_food  ...              5.0        2019-04-01
# 10657   331364  sample_food  ...              5.0        2019-04-01
# 10671   331378  sample_food  ...              5.0        2019-04-01
# 10685   331392  sample_food  ...              5.0        2019-04-01
# 10698   331405  sample_food  ...              5.0        2019-04-01
# 10711   331418  sample_food  ...              5.0        2019-04-01
# 10725   331432  sample_food  ...              5.0        2019-04-01
# 10739   331446  sample_food  ...              5.0        2019-04-01
# 10753   331460  sample_food  ...              5.0        2019-04-01
# 10767   331474  sample_food  ...              5.0        2019-04-01
# 10781   331488  sample_food  ...              5.0        2019-04-01
# 10795   331502  sample_food  ...              5.0        2019-04-01
# 10808   331515  sample_food  ...              5.0        2019-04-01
# 10820   331527  sample_food  ...              5.0        2019-04-01
# 10833   331540  sample_food  ...              5.0        2019-04-01
# 10846   331553  sample_food  ...              5.0        2019-04-01
# 10860   331567  sample_food  ...              5.0        2019-04-01
# 10874   331581  sample_food  ...              5.0        2019-04-01
# 10888   331595  sample_food  ...              5.0        2019-04-01
# 10901   331608  sample_food  ...              5.0        2019-04-01
# 10913   331620  sample_food  ...              5.0        2019-04-01
# 10927   331634  sample_food  ...              5.0        2019-04-01
# 10941   331648  sample_food  ...              5.0        2019-04-01
# 10953   331660  sample_food  ...              5.0        2019-04-01
# 10966   331673  sample_food  ...              5.0        2019-04-01
# 10978   331685  sample_food  ...              5.0        2019-04-01
# 10992   331699  sample_food  ...              5.0        2019-04-01
# 11006   331713  sample_food  ...              5.0        2019-04-01
# 11020   331727  sample_food  ...              5.0        2019-04-01
# 11044   331751  sample_food  ...              5.0        2019-04-01
# 11057   331764  sample_food  ...              5.0        2019-04-01
# 11069   331776  sample_food  ...              5.0        2019-04-01
# 11080   331787  sample_food  ...              5.0        2019-04-01
# 11102   331809  sample_food  ...              5.0        2019-04-01
# 11124   331831  sample_food  ...              5.0        2019-04-01
# 11146   331853  sample_food  ...              5.0        2019-04-01
# 11168   331875  sample_food  ...              5.0        2019-04-01
# 11191   331898  sample_food  ...              5.0        2019-04-01
# 11197   331904  sample_food  ...              5.0        2019-04-01
# 11204   331911  sample_food  ...              5.0        2019-04-01
# 11210   331917  sample_food  ...              5.0        2019-04-01
# 11224   331931  sample_food  ...              5.0        2019-04-01
# 11238   331945  sample_food  ...              5.0        2019-04-01
# 11254   331961  sample_food  ...              6.0        2019-04-01
# 11262   331969  sample_food  ...              6.0        2019-04-01
# 11270   331977  sample_food  ...              6.0        2019-04-01
# 11278   331985  sample_food  ...              6.0        2019-04-01
# 11286   331993  sample_food  ...              6.0        2019-04-01
# 11291   331998  sample_food  ...              6.0        2019-04-01
# 11296   332003  sample_food  ...              6.0        2019-04-01
# 11301   332008  sample_food  ...              6.0        2019-04-01
# 11306   332013  sample_food  ...              6.0        2019-04-01
# 11310   332017  sample_food  ...              6.0        2019-04-01
# 11315   332022  sample_food  ...              6.0        2019-04-01
# 11320   332027  sample_food  ...              6.0        2019-04-01
# 11328   332035  sample_food  ...              6.0        2019-04-01
# 11333   332040  sample_food  ...              6.0        2019-04-01
# 11341   332048  sample_food  ...              6.0        2019-04-01
# 11346   332053  sample_food  ...              6.0        2019-04-01
# 11351   332058  sample_food  ...              6.0        2019-04-01
# 11356   332063  sample_food  ...              6.0        2019-04-01
# 11361   332068  sample_food  ...              6.0        2019-04-01
# 11369   332076  sample_food  ...              6.0        2019-04-01
# 11377   332084  sample_food  ...              6.0        2019-04-01
# 11385   332092  sample_food  ...              6.0        2019-04-01
# 11393   332100  sample_food  ...              6.0        2019-04-01
# 11401   332108  sample_food  ...              6.0        2019-04-01
# 11406   332113  sample_food  ...              6.0        2019-04-01
# 11411   332118  sample_food  ...              6.0        2019-04-01
# 11416   332123  sample_food  ...              6.0        2019-04-01
# 11421   332128  sample_food  ...              6.0        2019-04-01
# 11425   332132  sample_food  ...              6.0        2019-04-01
# 11429   332136  sample_food  ...              6.0        2019-04-01
# 11434   332141  sample_food  ...              6.0        2019-04-01
# 11442   332149  sample_food  ...              6.0        2019-04-01
# 11447   332154  sample_food  ...              6.0        2019-04-01
# 11452   332159  sample_food  ...              6.0        2019-04-01
# 11457   332164  sample_food  ...              6.0        2019-04-01
# 11462   332169  sample_food  ...              6.0        2019-04-01
# 11467   332174  sample_food  ...              6.0        2019-04-01
# 11475   332182  sample_food  ...              6.0        2019-04-01
# 11483   332190  sample_food  ...              6.0        2019-04-01
# 11491   332198  sample_food  ...              6.0        2019-04-01
# 11499   332206  sample_food  ...              6.0        2019-04-01
# 11507   332214  sample_food  ...              6.0        2019-04-01
# 11515   332222  sample_food  ...              6.0        2019-04-01
# 11520   332227  sample_food  ...              6.0        2019-04-01
# 11525   332232  sample_food  ...              6.0        2019-04-01
# 11530   332237  sample_food  ...              6.0        2019-04-01
# 11535   332242  sample_food  ...              6.0        2019-04-01
# 11540   332247  sample_food  ...              6.0        2019-04-01
# 11545   332252  sample_food  ...              6.0        2019-04-01
# 11550   332257  sample_food  ...              6.0        2019-04-01
# 11555   332262  sample_food  ...              6.0        2019-04-01
# 11560   332267  sample_food  ...              6.0        2019-04-01
# 11565   332272  sample_food  ...              6.0        2019-04-01
# 11570   332277  sample_food  ...              6.0        2019-04-01
# 11576   332283  sample_food  ...              7.0        2019-04-01
# 11607   332314  sample_food  ...              7.0        2019-04-01
# 11658   332365  sample_food  ...              7.0        2019-04-01
# 11691   332398  sample_food  ...              9.0        2019-04-01
# 11697   332404  sample_food  ...              9.0        2019-04-01
# 11713   332420  sample_food  ...              9.0        2019-04-01
# 11717   332424  sample_food  ...              9.0        2019-04-01
# 11723   332430  sample_food  ...              9.0        2019-04-01
# 11739   332446  sample_food  ...              9.0        2019-04-01
# 11743   332450  sample_food  ...              9.0        2019-04-01
# 11747   332454  sample_food  ...              9.0        2019-04-01
# 11760   332467  sample_food  ...              9.0        2019-04-01
# 11764   332471  sample_food  ...              9.0        2019-04-01
# 11768   332475  sample_food  ...              9.0        2019-04-01
# 11772   332479  sample_food  ...              9.0        2019-04-01
# 11779   332486  sample_food  ...              9.0        2019-04-01
# 11796   332503  sample_food  ...              9.0        2019-04-01
# 11800   332507  sample_food  ...              9.0        2019-04-01
# 11807   332514  sample_food  ...              9.0        2019-04-01
# 11823   332530  sample_food  ...              9.0        2019-04-01
# 11827   332534  sample_food  ...              9.0        2019-04-01
# 11830   332537  sample_food  ...              9.0        2019-04-01
# 11844   332551  sample_food  ...              9.0        2019-04-01
# 11848   332555  sample_food  ...              9.0        2019-04-01
# 11852   332559  sample_food  ...              9.0        2019-04-01
# 11856   332563  sample_food  ...              9.0        2019-04-01
# 11874   332581  sample_food  ...              9.0        2019-04-01
# 11891   332598  sample_food  ...              9.0        2019-04-01
# 11906   332613  sample_food  ...              9.0        2019-04-01
# 11916   332623  sample_food  ...              9.0        2019-04-01
# 11998   332705  sample_food  ...              9.0        2019-04-01
# 12047   332754  sample_food  ...              9.0        2019-04-01
# 12064   332771  sample_food  ...              9.0        2019-04-01
# 12085   332792  sample_food  ...              7.0        2019-04-01
# 12139   332846  sample_food  ...              7.0        2019-04-01
# 12158   332865  sample_food  ...             18.0        2019-04-01
# 12173   332880  sample_food  ...             18.0        2019-04-01
# 12302   333009  sample_food  ...             11.0        2019-04-01
# 12309   333016  sample_food  ...             11.0        2019-04-01
# 12316   333023  sample_food  ...             11.0        2019-04-01
# 12323   333030  sample_food  ...             11.0        2019-04-01
# ...
# 13702   334409  sample_food  ...             25.0        2019-04-01
# 13709   334416  sample_food  ...             25.0        2019-04-01
# 13718   334425  sample_food  ...             25.0        2019-04-01
# 13727   334434  sample_food  ...             25.0        2019-04-01
# 13736   334443  sample_food  ...             25.0        2019-04-01
# 13745   334452  sample_food  ...             25.0        2019-04-01
# 13756   334463  sample_food  ...             25.0        2019-04-01
# 13760   334467  sample_food  ...             25.0        2019-04-01
# 13764   334471  sample_food  ...             25.0        2019-04-01
# 13769   334476  sample_food  ...             25.0        2019-04-01
# 13774   334481  sample_food  ...             25.0        2019-04-01
# 13779   334486  sample_food  ...             25.0        2019-04-01
# 13783   334490  sample_food  ...             25.0        2019-04-01
# 13788   334495  sample_food  ...             25.0        2019-04-01
# 13793   334500  sample_food  ...             25.0        2019-04-01
# 13802   334509  sample_food  ...             25.0        2019-04-01
# 13806   334513  sample_food  ...             25.0        2019-04-01
# 13810   334517  sample_food  ...             25.0        2019-04-01
# 13815   334522  sample_food  ...             25.0        2019-04-01
# 13820   334527  sample_food  ...             25.0        2019-04-01
# 13824   334531  sample_food  ...             25.0        2019-04-01
# 13830   334537  sample_food  ...             25.0        2019-04-01
# 13839   334546  sample_food  ...             25.0        2019-04-01
# 13848   334555  sample_food  ...             25.0        2019-04-01
# 13859   334566  sample_food  ...             25.0        2019-04-01
# 13874   334581  sample_food  ...             25.0        2019-04-01
# 13899   334606  sample_food  ...             25.0        2019-04-01
# 13922   334629  sample_food  ...             25.0        2019-04-01
# 13935   334642  sample_food  ...             25.0        2019-04-01
# 13945   334652  sample_food  ...             25.0        2019-04-01
# 13954   334661  sample_food  ...             25.0        2019-04-01
# 13974   334681  sample_food  ...             25.0        2019-04-01
# 13995   334702  sample_food  ...             25.0        2019-04-01
# 14014   334721  sample_food  ...             13.0        2019-04-01
# 14018   334725  sample_food  ...             13.0        2019-04-01
# 14043   334750  sample_food  ...             13.0        2019-04-01
# 14045   334752  sample_food  ...             13.0        2019-04-01
# 14072   334779  sample_food  ...             13.0        2019-04-01
# 14074   334781  sample_food  ...             13.0        2019-04-01
# 14080   334787  sample_food  ...             13.0        2019-04-01
# 14083   334790  sample_food  ...             13.0        2019-04-01
# 14085   334792  sample_food  ...             13.0        2019-04-01
# 14087   334794  sample_food  ...             13.0        2019-04-01
# 14089   334796  sample_food  ...             13.0        2019-04-01
# 14095   334802  sample_food  ...             13.0        2019-04-01
# 14097   334804  sample_food  ...             13.0        2019-04-01
# 14099   334806  sample_food  ...             13.0        2019-04-01
# 14101   334808  sample_food  ...             13.0        2019-04-01
# 14103   334810  sample_food  ...             13.0        2019-04-01
# 14105   334812  sample_food  ...             13.0        2019-04-01
# 14107   334814  sample_food  ...             13.0        2019-04-01
# 14109   334816  sample_food  ...             13.0        2019-04-01
# 14111   334818  sample_food  ...             13.0        2019-04-01
# 14117   334824  sample_food  ...             13.0        2019-04-01
# 14119   334826  sample_food  ...             13.0        2019-04-01
# 14121   334828  sample_food  ...             13.0        2019-04-01
# 14126   334833  sample_food  ...             13.0        2019-04-01
# 14128   334835  sample_food  ...             13.0        2019-04-01
# 14130   334837  sample_food  ...             13.0        2019-04-01
# 14132   334839  sample_food  ...             13.0        2019-04-01
# 14134   334841  sample_food  ...             13.0        2019-04-01
# 14136   334843  sample_food  ...             13.0        2019-04-01
# 14138   334845  sample_food  ...             13.0        2019-04-01
# 14140   334847  sample_food  ...             13.0        2019-04-01
# 14143   334850  sample_food  ...             13.0        2019-04-01
# 14153   334860  sample_food  ...             13.0        2019-04-01
# 14155   334862  sample_food  ...             13.0        2019-04-01
# 14164   334871  sample_food  ...             13.0        2019-04-01
# 14166   334873  sample_food  ...             13.0        2019-04-01
# 14170   334877  sample_food  ...             13.0        2019-04-01
# 14172   334879  sample_food  ...             13.0        2019-04-01
# 14174   334881  sample_food  ...             13.0        2019-04-01
# 14176   334883  sample_food  ...             13.0        2019-04-01
# 14178   334885  sample_food  ...             13.0        2019-04-01
# 14180   334887  sample_food  ...             13.0        2019-04-01
# 14182   334889  sample_food  ...             13.0        2019-04-01
# 14184   334891  sample_food  ...             13.0        2019-04-01
# 14186   334893  sample_food  ...             13.0        2019-04-01
# 14188   334895  sample_food  ...             13.0        2019-04-01
# 14192   334899  sample_food  ...             13.0        2019-04-01
# 14196   334903  sample_food  ...             13.0        2019-04-01
# 14210   334917  sample_food  ...             13.0        2019-04-01
# 14213   334920  sample_food  ...             13.0        2019-04-01
# 14216   334923  sample_food  ...             13.0        2019-04-01
# 14221   334928  sample_food  ...             13.0        2019-04-01
# 14224   334931  sample_food  ...             13.0        2019-04-01
# 14227   334934  sample_food  ...             13.0        2019-04-01
# 14230   334937  sample_food  ...             13.0        2019-04-01
# 14233   334940  sample_food  ...             13.0        2019-04-01
# 14238   334945  sample_food  ...             13.0        2019-04-01
# 14241   334948  sample_food  ...             13.0        2019-04-01
# 14244   334951  sample_food  ...             13.0        2019-04-01
# 14247   334954  sample_food  ...             13.0        2019-04-01
# 14250   334957  sample_food  ...             13.0        2019-04-01
# 14253   334960  sample_food  ...             13.0        2019-04-01
# 14257   334964  sample_food  ...             13.0        2019-04-01
# 14260   334967  sample_food  ...             13.0        2019-04-01
# 14270   334977  sample_food  ...             13.0        2019-04-01
# 14272   334979  sample_food  ...             13.0        2019-04-01
# 14281   334988  sample_food  ...             13.0        2019-04-01
# 14283   334990  sample_food  ...             13.0        2019-04-01
# 14288   334995  sample_food  ...             13.0        2019-04-01
# 14290   334997  sample_food  ...             13.0        2019-04-01
# 14292   334999  sample_food  ...             13.0        2019-04-01
# 14294   335001  sample_food  ...             13.0        2019-04-01
# 14296   335003  sample_food  ...             13.0        2019-04-01
# 14298   335005  sample_food  ...             13.0        2019-04-01
# 14300   335007  sample_food  ...             13.0        2019-04-01
# 14302   335009  sample_food  ...             13.0        2019-04-01
# 14304   335011  sample_food  ...             13.0        2019-04-01
# 14306   335013  sample_food  ...             13.0        2019-04-01
# 14309   335016  sample_food  ...             13.0        2019-04-01
# 14318   335025  sample_food  ...             13.0        2019-04-01
# 14320   335027  sample_food  ...             13.0        2019-04-01
# 14329   335036  sample_food  ...             13.0        2019-04-01
# 14331   335038  sample_food  ...             13.0        2019-04-01
# 14336   335043  sample_food  ...             13.0        2019-04-01
# 14338   335045  sample_food  ...             13.0        2019-04-01
# 14340   335047  sample_food  ...             13.0        2019-04-01
# 14342   335049  sample_food  ...             13.0        2019-04-01
# 14344   335051  sample_food  ...             13.0        2019-04-01
# 14346   335053  sample_food  ...             13.0        2019-04-01
# 14348   335055  sample_food  ...             13.0        2019-04-01
# 14350   335057  sample_food  ...             13.0        2019-04-01
# 14352   335059  sample_food  ...             13.0        2019-04-01
# 14355   335062  sample_food  ...             13.0        2019-04-01
# 14358   335065  sample_food  ...             13.0        2019-04-01
# 14372   335079  sample_food  ...             13.0        2019-04-01
# 14374   335081  sample_food  ...             13.0        2019-04-01
# 14378   335085  sample_food  ...             13.0        2019-04-01
# 14380   335087  sample_food  ...             13.0        2019-04-01
# 14382   335089  sample_food  ...             13.0        2019-04-01
# 14384   335091  sample_food  ...             13.0        2019-04-01
# 14386   335093  sample_food  ...             13.0        2019-04-01
# 14390   335097  sample_food  ...             13.0        2019-04-01
# 14392   335099  sample_food  ...             13.0        2019-04-01
# 14394   335101  sample_food  ...             13.0        2019-04-01
# 14396   335103  sample_food  ...             13.0        2019-04-01
# 14398   335105  sample_food  ...             13.0        2019-04-01
# 14400   335107  sample_food  ...             13.0        2019-04-01
# 14403   335110  sample_food  ...             18.0        2019-04-01
# 14410   335117  sample_food  ...             18.0        2019-04-01
# 14415   335122  sample_food  ...             18.0        2019-04-01
# 14430   335137  sample_food  ...             18.0        2019-04-01
# 14446   335153  sample_food  ...             18.0        2019-04-01
# 14462   335169  sample_food  ...             18.0        2019-04-01
# 14478   335185  sample_food  ...             18.0        2019-04-01
# 14495   335202  sample_food  ...             18.0        2019-04-01
# 14501   335208  sample_food  ...             18.0        2019-04-01
# 14517   335224  sample_food  ...             18.0        2019-04-01
# 15389   746786  sample_food  ...             10.0        2019-12-16
# 15425   746822  sample_food  ...             10.0        2019-12-16
# 15433   746830  sample_food  ...             10.0        2019-12-16
# 15448   746845  sample_food  ...             10.0        2019-12-16
# 15556   746953  sample_food  ...              1.0        2019-12-16
# 15595   746992  sample_food  ...              1.0        2019-12-16
# 15617   747014  sample_food  ...              1.0        2019-12-16
# 15658   747055  sample_food  ...              1.0        2019-12-16
# 15699   747096  sample_food  ...              1.0        2019-12-16
# 15731   747128  sample_food  ...              1.0        2019-12-16
# 15738   747135  sample_food  ...              1.0        2019-12-16
# 15793   747190  sample_food  ...              1.0        2019-12-16
# 15799   747196  sample_food  ...              1.0        2019-12-16
# 15871   747268  sample_food  ...              1.0        2019-12-16
# 15906   747303  sample_food  ...              1.0        2019-12-16
# 15913   747310  sample_food  ...              1.0        2019-12-16
# 15927   747324  sample_food  ...              1.0        2019-12-16
# 16052   747449  sample_food  ...             11.0        2019-12-16
# 16068   747465  sample_food  ...             11.0        2019-12-16
# 16099   747496  sample_food  ...             11.0        2019-12-16
# 16134   747531  sample_food  ...             11.0        2019-12-16
# 16164   747561  sample_food  ...             11.0        2019-12-16
# 16224   747621  sample_food  ...             11.0        2019-12-16
# 16260   747657  sample_food  ...             11.0        2019-12-16
# 16297   747694  sample_food  ...              1.0        2019-12-16
# 16312   747709  sample_food  ...              1.0        2019-12-16
# 16342   747739  sample_food  ...              1.0        2019-12-16
# 16840   748237  sample_food  ...              4.0        2019-12-16
# 16882   748279  sample_food  ...              4.0        2019-12-16
# 16927   748324  sample_food  ...              4.0        2019-12-16
# 16970   748367  sample_food  ...              4.0        2019-12-16
# 17191   748588  sample_food  ...              NaN        2019-12-16
# 17519   748916  sample_food  ...              1.0        2019-12-16
# 17571   748968  sample_food  ...             10.0        2019-12-16
# 17577   748974  sample_food  ...             10.0        2019-12-16
# 17647   749044  sample_food  ...             10.0        2019-12-16
# 17678   749075  sample_food  ...             10.0        2019-12-16
# 17719   749116  sample_food  ...             10.0        2019-12-16
# 17758   749155  sample_food  ...             10.0        2019-12-16
# 17800   749197  sample_food  ...             10.0        2019-12-16
# 17836   749233  sample_food  ...             10.0        2019-12-16
# 17878   749275  sample_food  ...             10.0        2019-12-16
# 17897   749294  sample_food  ...              NaN        2019-12-16
# 17909   749306  sample_food  ...             10.0        2019-12-16
# 17954   749351  sample_food  ...             10.0        2019-12-16
# 18024   789772  sample_food  ...              1.0        2020-04-01
# 18081   789829  sample_food  ...             20.0        2020-04-01
# 18143   789891  sample_food  ...             20.0        2020-04-01
# 18204   789952  sample_food  ...             20.0        2020-04-01
# 18215   789963  sample_food  ...             20.0        2020-04-01
# 18271   790019  sample_food  ...             20.0        2020-04-01
# 18282   790030  sample_food  ...             20.0        2020-04-01
# 18338   790086  sample_food  ...             20.0        2020-04-01
# 18358   790106  sample_food  ...             20.0        2020-04-01
# 18399   790147  sample_food  ...             20.0        2020-04-01
# 18421   790169  sample_food  ...             20.0        2020-04-01
# 18467   790215  sample_food  ...             20.0        2020-04-01
# 18529   790277  sample_food  ...              1.0        2020-04-01
# 18761   790509  sample_food  ...             11.0        2020-04-01
# 18830   790578  sample_food  ...             11.0        2020-04-01
# 18899   790647  sample_food  ...              9.0        2020-04-01
# 18997   790745  sample_food  ...              9.0        2020-04-01
# 19001   790749  sample_food  ...              NaN        2020-04-01
# 19004   790752  sample_food  ...              NaN        2020-04-01
# 19007   790755  sample_food  ...              9.0        2020-04-01
# 19012   790760  sample_food  ...              9.0        2020-04-01
# 19018   790766  sample_food  ...              NaN        2020-04-01
# 19020   790768  sample_food  ...              NaN        2020-04-01
# 19027   790775  sample_food  ...              9.0        2020-04-01
# 19088   790836  sample_food  ...              9.0        2020-04-01
# 19244  1104593  sample_food  ...             11.0        2020-10-30
# 19299  1104648  sample_food  ...             16.0        2020-10-30
# 19357  1104706  sample_food  ...             16.0        2020-10-30
# 19367  1104716  sample_food  ...             16.0        2020-10-30
# 19418  1104767  sample_food  ...             20.0        2020-10-30
# 19427  1104776  sample_food  ...             20.0        2020-10-30
# 19457  1104813  sample_food  ...             20.0        2020-10-30
# 19512  1104868  sample_food  ...             20.0        2020-10-30
# 19558  1104914  sample_food  ...             11.0        2020-10-30
# 19959  1105315  sample_food  ...              9.0        2020-10-30
# 20075  1105431  sample_food  ...              9.0        2020-10-30
# 20192  1105548  sample_food  ...              9.0        2020-10-30
# 20309  1105665  sample_food  ...              9.0        2020-10-30
# 20426  1105782  sample_food  ...              9.0        2020-10-30
#
# [1026 rows x 5 columns]

# %%
mark_acui_noduplicates = df[df['data_type'] == 'market_acquisition'].drop_duplicates(subset='description')
len(mark_acui_noduplicates)
# Out:
# 3519

# %%
df['data_type'].where(df['data_type'] == 'agricultural_acquisition').count()
# Out:
# 810

# %%
# it seems that foundation food is very limited and not all the ingredients end up here. Even here we have some data from restaurants
df_foundation_df = df[df['data_type'] == 'foundation_food'].drop_duplicates(subset='description')
df_foundation_df[df_foundation_df['description'].str.contains('flour', case=False)]
# Out:
#         fdc_id        data_type  ... food_category_id  publication_date
# 18142   789890  foundation_food  ...             20.0        2020-04-01
# 18203   789951  foundation_food  ...             20.0        2020-04-01
# 18270   790018  foundation_food  ...             20.0        2020-04-01
# 18337   790085  foundation_food  ...             20.0        2020-04-01
# 18398   790146  foundation_food  ...             20.0        2020-04-01
# 18466   790214  foundation_food  ...             20.0        2020-04-01
# 18528   790276  foundation_food  ...             20.0        2020-04-01
# 19356  1104705  foundation_food  ...             16.0        2020-10-30
# 19417  1104766  foundation_food  ...             16.0        2020-10-30
# 19456  1104812  foundation_food  ...             20.0        2020-10-30
# 19511  1104867  foundation_food  ...             20.0        2020-10-30
# 19557  1104913  foundation_food  ...             20.0        2020-10-30
#
# [12 rows x 5 columns]

# %%
df['data_type'].where(df['data_type'] == 'sub_sample_food').count()
# Out:
# 12400

# %%
market_acquisition_df = df[df['data_type'] == 'market_acquisition'].copy()
#market_acquisition_df['description'].unique().tolist();
market_acquisition_df[market_acquisition_df['description'].str.contains('pork', case=False)]
# Out:
#        fdc_id           data_type  ... food_category_id  publication_date
# 4819   325526  market_acquisition  ...              7.0        2019-04-01
# 4820   325527  market_acquisition  ...              7.0        2019-04-01
# 4821   325528  market_acquisition  ...              7.0        2019-04-01
# 4822   325529  market_acquisition  ...              7.0        2019-04-01
# 4827   325534  market_acquisition  ...              7.0        2019-04-01
# 4828   325535  market_acquisition  ...              7.0        2019-04-01
# 4829   325536  market_acquisition  ...              7.0        2019-04-01
# 4830   325537  market_acquisition  ...              7.0        2019-04-01
# 4835   325542  market_acquisition  ...              7.0        2019-04-01
# 4836   325543  market_acquisition  ...              7.0        2019-04-01
# 4837   325544  market_acquisition  ...              7.0        2019-04-01
# 4838   325545  market_acquisition  ...              7.0        2019-04-01
# 4843   325550  market_acquisition  ...              7.0        2019-04-01
# 4844   325551  market_acquisition  ...              7.0        2019-04-01
# 4845   325552  market_acquisition  ...              7.0        2019-04-01
# 4853   325560  market_acquisition  ...              7.0        2019-04-01
# 4854   325561  market_acquisition  ...              7.0        2019-04-01
# 4855   325562  market_acquisition  ...              7.0        2019-04-01
# 4856   325563  market_acquisition  ...              7.0        2019-04-01
# 4866   325573  market_acquisition  ...              7.0        2019-04-01
# 4867   325574  market_acquisition  ...              7.0        2019-04-01
# 4868   325575  market_acquisition  ...              7.0        2019-04-01
# 4869   325576  market_acquisition  ...              7.0        2019-04-01
# 4874   325581  market_acquisition  ...              7.0        2019-04-01
# 4875   325582  market_acquisition  ...              7.0        2019-04-01
# 4876   325583  market_acquisition  ...              7.0        2019-04-01
# 4877   325584  market_acquisition  ...              7.0        2019-04-01
# 4892   325599  market_acquisition  ...              7.0        2019-04-01
# 4893   325600  market_acquisition  ...              7.0        2019-04-01
# 4894   325601  market_acquisition  ...              7.0        2019-04-01
# 4895   325602  market_acquisition  ...              7.0        2019-04-01
# 4903   325610  market_acquisition  ...              7.0        2019-04-01
# 4904   325611  market_acquisition  ...              7.0        2019-04-01
# 4918   325625  market_acquisition  ...              7.0        2019-04-01
# 4919   325626  market_acquisition  ...              7.0        2019-04-01
# 4920   325627  market_acquisition  ...              7.0        2019-04-01
# 4921   325628  market_acquisition  ...              7.0        2019-04-01
# 4935   325642  market_acquisition  ...              7.0        2019-04-01
# 4936   325643  market_acquisition  ...              7.0        2019-04-01
# 4937   325644  market_acquisition  ...              7.0        2019-04-01
# 4938   325645  market_acquisition  ...              7.0        2019-04-01
# 12086  332793  market_acquisition  ...              7.0        2019-04-01
# 12087  332794  market_acquisition  ...              7.0        2019-04-01
# 12088  332795  market_acquisition  ...              7.0        2019-04-01
# 12089  332796  market_acquisition  ...              7.0        2019-04-01
# 12094  332801  market_acquisition  ...              7.0        2019-04-01
# 12095  332802  market_acquisition  ...              7.0        2019-04-01
# 12096  332803  market_acquisition  ...              7.0        2019-04-01
# 12097  332804  market_acquisition  ...              7.0        2019-04-01
# 12098  332805  market_acquisition  ...              7.0        2019-04-01
# 12103  332810  market_acquisition  ...              7.0        2019-04-01
# 12104  332811  market_acquisition  ...              7.0        2019-04-01
# 12105  332812  market_acquisition  ...              7.0        2019-04-01
# 12121  332828  market_acquisition  ...              7.0        2019-04-01
# 12122  332829  market_acquisition  ...              7.0        2019-04-01
# 12123  332830  market_acquisition  ...              7.0        2019-04-01
# 12124  332831  market_acquisition  ...              7.0        2019-04-01
# 12125  332832  market_acquisition  ...              7.0        2019-04-01
# 12126  332833  market_acquisition  ...              7.0        2019-04-01
# 12140  332847  market_acquisition  ...              7.0        2019-04-01
# 12141  332848  market_acquisition  ...              7.0        2019-04-01
# 12142  332849  market_acquisition  ...              7.0        2019-04-01
# 12143  332850  market_acquisition  ...              7.0        2019-04-01
# 13542  334249  market_acquisition  ...             25.0        2019-04-01
# 13543  334250  market_acquisition  ...             25.0        2019-04-01
# 13544  334251  market_acquisition  ...             25.0        2019-04-01
# 13561  334268  market_acquisition  ...             25.0        2019-04-01
# 13562  334269  market_acquisition  ...             25.0        2019-04-01
# 13579  334286  market_acquisition  ...             25.0        2019-04-01
# 13580  334287  market_acquisition  ...             25.0        2019-04-01
# 13581  334288  market_acquisition  ...             25.0        2019-04-01
# 13598  334305  market_acquisition  ...             25.0        2019-04-01
# 13599  334306  market_acquisition  ...             25.0        2019-04-01
# 13600  334307  market_acquisition  ...             25.0        2019-04-01
# 13601  334308  market_acquisition  ...             25.0        2019-04-01
# 13617  334324  market_acquisition  ...             25.0        2019-04-01
# 13618  334325  market_acquisition  ...             25.0        2019-04-01
# 13619  334326  market_acquisition  ...             25.0        2019-04-01
# 13620  334327  market_acquisition  ...             25.0        2019-04-01
# 13636  334343  market_acquisition  ...             25.0        2019-04-01
# 13637  334344  market_acquisition  ...             25.0        2019-04-01
# 13638  334345  market_acquisition  ...             25.0        2019-04-01
# 13639  334346  market_acquisition  ...             25.0        2019-04-01
# 13656  334363  market_acquisition  ...             25.0        2019-04-01
# 13657  334364  market_acquisition  ...             25.0        2019-04-01
# 13658  334365  market_acquisition  ...             25.0        2019-04-01
# 13663  334370  market_acquisition  ...             25.0        2019-04-01
# 13664  334371  market_acquisition  ...             25.0        2019-04-01
# 13665  334372  market_acquisition  ...             25.0        2019-04-01
# 13670  334377  market_acquisition  ...             25.0        2019-04-01
# 13671  334378  market_acquisition  ...             25.0        2019-04-01
# 13672  334379  market_acquisition  ...             25.0        2019-04-01
# 13673  334380  market_acquisition  ...             25.0        2019-04-01
# 13674  334381  market_acquisition  ...             25.0        2019-04-01
# 13679  334386  market_acquisition  ...             25.0        2019-04-01
# 13680  334387  market_acquisition  ...             25.0        2019-04-01
# 13681  334388  market_acquisition  ...             25.0        2019-04-01
# 13686  334393  market_acquisition  ...             25.0        2019-04-01
# 13687  334394  market_acquisition  ...             25.0        2019-04-01
# 13688  334395  market_acquisition  ...             25.0        2019-04-01
# 13689  334396  market_acquisition  ...             25.0        2019-04-01
# 13690  334397  market_acquisition  ...             25.0        2019-04-01
# 13695  334402  market_acquisition  ...             25.0        2019-04-01
# 13696  334403  market_acquisition  ...             25.0        2019-04-01
# 13697  334404  market_acquisition  ...             25.0        2019-04-01
# 13703  334410  market_acquisition  ...             25.0        2019-04-01
# 13704  334411  market_acquisition  ...             25.0        2019-04-01
# 13705  334412  market_acquisition  ...             25.0        2019-04-01
# 13710  334417  market_acquisition  ...             25.0        2019-04-01
# 13711  334418  market_acquisition  ...             25.0        2019-04-01
# 13712  334419  market_acquisition  ...             25.0        2019-04-01
# 13713  334420  market_acquisition  ...             25.0        2019-04-01
# 13714  334421  market_acquisition  ...             25.0        2019-04-01
# 13719  334426  market_acquisition  ...             25.0        2019-04-01
# 13720  334427  market_acquisition  ...             25.0        2019-04-01
# 13721  334428  market_acquisition  ...             25.0        2019-04-01
# 13722  334429  market_acquisition  ...             25.0        2019-04-01
# 13723  334430  market_acquisition  ...             25.0        2019-04-01
# 13728  334435  market_acquisition  ...             25.0        2019-04-01
# 13729  334436  market_acquisition  ...             25.0        2019-04-01
# 13730  334437  market_acquisition  ...             25.0        2019-04-01
# 13731  334438  market_acquisition  ...             25.0        2019-04-01
# 13732  334439  market_acquisition  ...             25.0        2019-04-01
# 13737  334444  market_acquisition  ...             25.0        2019-04-01
# 13738  334445  market_acquisition  ...             25.0        2019-04-01
# 13739  334446  market_acquisition  ...             25.0        2019-04-01
# 13740  334447  market_acquisition  ...             25.0        2019-04-01
# 13741  334448  market_acquisition  ...             25.0        2019-04-01
# 13746  334453  market_acquisition  ...             25.0        2019-04-01
# 13747  334454  market_acquisition  ...             25.0        2019-04-01
# 13748  334455  market_acquisition  ...             25.0        2019-04-01
# 13749  334456  market_acquisition  ...             25.0        2019-04-01
# 13750  334457  market_acquisition  ...             25.0        2019-04-01
# 13831  334538  market_acquisition  ...             25.0        2019-04-01
# 13840  334547  market_acquisition  ...             25.0        2019-04-01
# 13849  334556  market_acquisition  ...             25.0        2019-04-01
# 13850  334557  market_acquisition  ...             25.0        2019-04-01
# 13851  334558  market_acquisition  ...             25.0        2019-04-01
# 13860  334567  market_acquisition  ...             25.0        2019-04-01
# 13861  334568  market_acquisition  ...             25.0        2019-04-01
# 13862  334569  market_acquisition  ...             25.0        2019-04-01
# 13863  334570  market_acquisition  ...             25.0        2019-04-01
# 13864  334571  market_acquisition  ...             25.0        2019-04-01
# 13865  334572  market_acquisition  ...             25.0        2019-04-01
# 13866  334573  market_acquisition  ...             25.0        2019-04-01
# 13875  334582  market_acquisition  ...             25.0        2019-04-01
# 13876  334583  market_acquisition  ...             25.0        2019-04-01
# 13877  334584  market_acquisition  ...             25.0        2019-04-01
# 13878  334585  market_acquisition  ...             25.0        2019-04-01
# 13879  334586  market_acquisition  ...             25.0        2019-04-01
# 13900  334607  market_acquisition  ...             25.0        2019-04-01
# 13901  334608  market_acquisition  ...             25.0        2019-04-01
#
# [152 rows x 5 columns]

# %%
market_acquisition_df = df[df['data_type'] == 'agricultural_acquisition'].copy()
market_acquisition_df['description'].unique().tolist()
# Out:
# ['Beans, Dry, Dark Red Kidney, 11F-8074 (0% moisture)',
#  'Beans, Dry, Dark Red Kidney, 11F-8130 (0% moisture)',
#  'Beans, Dry, Dark Red Kidney, 11F-8040 (0% moisture)',
#  'Beans, Dry, Dark Red Kidney, 11F-8132 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8082 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8190 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8034 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8188 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8197 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8084 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8193 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8058 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8149 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8059 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8124 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8041 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8156 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8019 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8136 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8018 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8187 (0% moisture)',
#  'Beans, Dry, Pink, 11F-8105 (0% moisture)',
#  'Beans, Dry, Pink, 483 (0% moisture)',
#  'Beans, Dry, Pink, 641 (0% moisture)',
#  'Beans, Dry, Pink, 481 (0% moisture)',
#  'Beans, Dry, Pink, 817 (0% moisture)',
#  'Beans, Dry, Pink, 399 (0% moisture)',
#  'Beans, Dry, Pink, 779 (0% moisture)',
#  'Beans, Dry, Pink, 430 (0% moisture)',
#  'Beans, Dry, Pink, 699 (0% moisture)',
#  'Beans, Dry, Pink, 478 (0% moisture)',
#  'Beans, Dry, Pink, 803 (0% moisture)',
#  'Beans, Dry, Pink, 504 (0% moisture)',
#  'Beans, Dry, Pink, 636 (0% moisture)',
#  'Beans, Dry, Pink, 404 (0% moisture)',
#  'Beans, Dry, Pink, 794 (0% moisture)',
#  'Beans, Dry, Pink, 461 (0% moisture)',
#  'Beans, Dry, Pink, 629 (0% moisture)',
#  'Beans, Dry, Pink, 411 (0% moisture)',
#  'Beans, Dry, Pink, 732 (0% moisture)',
#  'Beans, Dry, Pink, 342 (0% moisture)',
#  'Beans, Dry, Pink, 502 (0% moisture)',
#  'Beans, Dry, Pink, 819 (0% moisture)',
#  'Beans, Dry, Pink, 359 (0% moisture)',
#  'Beans, Dry, Pink, 687 (0% moisture)',
#  'Beans, Dry, Pink, 321 (0% moisture)',
#  'Beans, Dry, Pink, 739 (0% moisture)',
#  'Beans, Dry, Pink, 338 (0% moisture)',
#  'Beans, Dry, Pink, 712 (0% moisture)',
#  'Beans, Dry, Pink, 445 (0% moisture)',
#  'Beans, Dry, Pink, 796 (0% moisture)',
#  'Beans, Dry, Pink, 477 (0% moisture)',
#  'Beans, Dry, Pink, 752 (0% moisture)',
#  'Beans, Dry, Pink, 486 (0% moisture)',
#  'Beans, Dry, Pink, 701 (0% moisture)',
#  'Beans, Dry, Pink, 433 (0% moisture)',
#  'Beans, Dry, Pink, 725 (0% moisture)',
#  'Beans, Dry, Pink, 448 (0% moisture)',
#  'Beans, Dry, Pink, 652 (0% moisture)',
#  'Beans, Dry, Pink, 354 (0% moisture)',
#  'Beans, Dry, Pink, 664 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8043 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8162 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8007 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8195 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8027 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8165 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8098 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8107 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8028 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8179 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8030 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8143 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8004 (0% moisture)',
#  'Beans, Dry, Navy, 11F-8183 (0% moisture)',
#  'Beans, Dry, Navy, 287 (0% moisture)',
#  'Beans, Dry, Navy, 613 (0% moisture)',
#  'Beans, Dry, Navy, 289 (0% moisture)',
#  'Beans, Dry, Navy, 560 (0% moisture)',
#  'Beans, Dry, Navy, 279 (0% moisture)',
#  'Beans, Dry, Navy, 586 (0% moisture)',
#  'Beans, Dry, Navy, 233 (0% moisture)',
#  'Beans, Dry, Navy, 584 (0% moisture)',
#  'Beans, Dry, Navy, 229 (0% moisture)',
#  'Beans, Dry, Navy, 603 (0% moisture)',
#  'Beans, Dry, Navy, 299 (0% moisture)',
#  'Beans, Dry, Navy, 585 (0% moisture)',
#  'Beans, Dry, Navy, 292 (0% moisture)',
#  'Beans, Dry, Navy, 576 (0% moisture)',
#  'Beans, Dry, Navy, 261 (0% moisture)',
#  'Beans, Dry, Navy, 582 (0% moisture)',
#  'Beans, Dry, Navy, 230 (0% moisture)',
#  'Beans, Dry, Navy, 557 (0% moisture)',
#  'Beans, Dry, Navy, 242 (0% moisture)',
#  'Beans, Dry, Navy, 556 (0% moisture)',
#  'Beans, Dry, Navy, 320 (0% moisture)',
#  'Beans, Dry, Navy, 595 (0% moisture)',
#  'Beans, Dry, Navy, 311 (0% moisture)',
#  'Beans, Dry, Navy, 578 (0% moisture)',
#  'Beans, Dry, Navy, 280 (0% moisture)',
#  'Beans, Dry, Navy, 598 (0% moisture)',
#  'Beans, Dry, Navy, 245 (0% moisture)',
#  'Beans, Dry, Navy, 605 (0% moisture)',
#  'Beans, Dry, Navy, 262 (0% moisture)',
#  'Beans, Dry, Navy, 588 (0% moisture)',
#  'Beans, Dry, Navy, 284 (0% moisture)',
#  'Beans, Dry, Navy, 599 (0% moisture)',
#  'Beans, Dry, Navy, 256 (0% moisture)',
#  'Beans, Dry, Navy, 524 (0% moisture)',
#  'Beans, Dry, Navy, 476 (0% moisture)',
#  'Beans, Dry, Navy, 260 (0% moisture)',
#  'Beans, Dry, Navy, 771 (0% moisture)',
#  'Beans, Dry, Navy, 627 (0% moisture)',
#  'Beans, Dry, Navy, 255 (0% moisture)',
#  'Beans, Dry, Navy, 568 (0% moisture)',
#  'Beans, Dry, Navy, 294 (0% moisture)',
#  'Beans, Dry, Navy, 589 (0% moisture)',
#  'Beans, Dry, Navy, 246 (0% moisture)',
#  'Beans, Dry, Navy, 587 (0% moisture)',
#  'Beans, Dry, Navy, 236 (0% moisture)',
#  'Beans, Dry, Navy, 530 (0% moisture)',
#  'Beans, Dry, Navy, 241 (0% moisture)',
#  'Beans, Dry, Navy, 554 (0% moisture)',
#  'Beans, Dry, Navy, 234 (0% moisture)',
#  'Beans, Dry, Navy, 626 (0% moisture)',
#  'Beans, Dry, Navy, 228 (0% moisture)',
#  'Beans, Dry, Navy, 623 (0% moisture)',
#  'Beans, Dry, Navy, 268 (0% moisture)',
#  'Beans, Dry, Navy, 548 (0% moisture)',
#  'Beans, Dry, Navy, 386 (0% moisture)',
#  'Beans, Dry, Navy, 719 (0% moisture)',
#  'Beans, Dry, Navy, 253 (0% moisture)',
#  'Beans, Dry, Navy, 523 (0% moisture)',
#  'Beans, Dry, Navy, 319 (0% moisture)',
#  'Beans, Dry, Navy, 609 (0% moisture)',
#  'Beans, Dry, Navy, 422 (0% moisture)',
#  'Beans, Dry, Navy, 313 (0% moisture)',
#  'Beans, Dry, Navy, 721 (0% moisture)',
#  'Beans, Dry, Navy, 561 (0% moisture)',
#  'Beans, Dry, Navy, 283 (0% moisture)',
#  'Beans, Dry, Navy, 525 (0% moisture)',
#  'Beans, Dry, Navy, 264 (0% moisture)',
#  'Beans, Dry, Navy, 567 (0% moisture)',
#  'Beans, Dry, Navy, 226 (0% moisture)',
#  'Beans, Dry, Navy, 558 (0% moisture)',
#  'Beans, Dry, Navy, 281 (0% moisture)',
#  'Beans, Dry, Navy, 546 (0% moisture)',
#  'Beans, Dry, Navy, 295 (0% moisture)',
#  'Beans, Dry, Navy, 543 (0% moisture)',
#  'Beans, Dry, Navy, 220 (0% moisture)',
#  'Beans, Dry, Navy, 521 (0% moisture)',
#  'Beans, Dry, Navy, 213 (0% moisture)',
#  'Beans, Dry, Navy, 628 (0% moisture)',
#  'Beans, Dry, Navy, 237 (0% moisture)',
#  'Beans, Dry, Navy, 532 (0% moisture)',
#  'Beans, Dry, Navy, 316 (0% moisture)',
#  'Beans, Dry, Navy, 535 (0% moisture)',
#  'Beans, Dry, Navy, 290 (0% moisture)',
#  'Beans, Dry, Navy, 539 (0% moisture)',
#  'Beans, Dry, Navy, 307 (0% moisture)',
#  'Beans, Dry, Navy, 614 (0% moisture)',
#  'Beans, Dry, Navy, 252 (0% moisture)',
#  'Beans, Dry, Navy, 565 (0% moisture)',
#  'Beans, Dry, Navy, 277 (0% moisture)',
#  'Beans, Dry, Navy, 559 (0% moisture)',
#  'Beans, Dry, Navy, 216 (0% moisture)',
#  'Beans, Dry, Navy, 541 (0% moisture)',
#  'Beans, Dry, Navy, 312 (0% moisture)',
#  'Beans, Dry, Navy, 551 (0% moisture)',
#  'Beans, Dry, Navy, 257 (0% moisture)',
#  'Beans, Dry, Navy, 555 (0% moisture)',
#  'Beans, Dry, Navy, 308 (0% moisture)',
#  'Beans, Dry, Navy, 612 (0% moisture)',
#  'Beans, Dry, Light Red Kidney, 11F-8186 (0% moisture)',
#  'Beans, Dry, Brown, 351 (0% moisture)',
#  'Beans, Dry, Brown, 679 (0% moisture)',
#  'Beans, Dry, Flor de Mayo, 443 (0% moisture)',
#  'Beans, Dry, Flor de Mayo, 823 (0% moisture)',
#  'Beans, Dry, Carioca, 11F-8001 (0% moisture)',
#  'Beans, Dry, Carioca, 11F-8104 (0% moisture)',
#  'Beans, Dry, Carioca, 217 (0% moisture)',
#  'Beans, Dry, Carioca, 622 (0% moisture)',
#  'Beans, Dry, Tan, 11F-8005 (0% moisture)',
#  'Beans, Dry, Tan, 11F-8175 (0% moisture)',
#  'Beans, Dry, Tan, 11F-8042 (0% moisture)',
#  'Beans, Dry, Tan, 11F-8148 (0% moisture)',
#  'Beans, Dry, Tan, 302 (0% moisture)',
#  'Beans, Dry, Tan, 540 (0% moisture)',
#  'Beans, Dry, Tan, 231 (0% moisture)',
#  'Beans, Dry, Tan, 577 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8006 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8106 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8091 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8147 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8075 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8157 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8096 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8191 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8012 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8170 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8099 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8114 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8024 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8151 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8081 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8133 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8035 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8164 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8048 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8144 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8088 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8159 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8069 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8101 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8089 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8167 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8094 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8121 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8049 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8176 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8095 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8173 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8038 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8196 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8047 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8108 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8031 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8120 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8078 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8100 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8032 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8109 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8037 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8182 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8054 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8181 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8055 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8166 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8079 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8118 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8026 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8103 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8070 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8198 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8083 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8126 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8076 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8178 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8065 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8102 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8072 (0% moisture)',
#  'Beans, Dry, Pinto, 11F-8189 (0% moisture)',
#  'Beans, Dry, Pinto, 465 (0% moisture)',
#  'Beans, Dry, Pinto, 761 (0% moisture)',
#  'Beans, Dry, Pinto, 435 (0% moisture)',
#  'Beans, Dry, Pinto, 743 (0% moisture)',
#  'Beans, Dry, Pinto, 326 (0% moisture)',
#  'Beans, Dry, Pinto, 667 (0% moisture)',
#  'Beans, Dry, Pinto, 365 (0% moisture)',
#  'Beans, Dry, Pinto, 696 (0% moisture)',
#  'Beans, Dry, Pinto, 334 (0% moisture)',
#  'Beans, Dry, Pinto, 684 (0% moisture)',
#  'Beans, Dry, Pinto, 360 (0% moisture)',
#  'Beans, Dry, Pinto, 784 (0% moisture)',
#  'Beans, Dry, Pinto, 436 (0% moisture)',
#  'Beans, Dry, Pinto, 825 (0% moisture)',
#  'Beans, Dry, Pinto, 377 (0% moisture)',
#  'Beans, Dry, Pinto, 805 (0% moisture)',
#  'Beans, Dry, Pinto, 462 (0% moisture)',
#  'Beans, Dry, Pinto, 633 (0% moisture)',
#  'Beans, Dry, Pinto, 270 (0% moisture)',
#  'Beans, Dry, Pinto, 442 (0% moisture)',
#  'Beans, Dry, Pinto, 591 (0% moisture)',
#  'Beans, Dry, Pinto, 814 (0% moisture)',
#  'Beans, Dry, Pinto, 503 (0% moisture)',
#  'Beans, Dry, Pinto, 676 (0% moisture)',
#  'Beans, Dry, Pinto, 356 (0% moisture)',
#  'Beans, Dry, Pinto, 816 (0% moisture)',
#  'Beans, Dry, Pinto, 218 (0% moisture)',
#  'Beans, Dry, Pinto, 563 (0% moisture)',
#  'Beans, Dry, Pinto, 366 (0% moisture)',
#  'Beans, Dry, Pinto, 717 (0% moisture)',
#  'Beans, Dry, Pinto, 437 (0% moisture)',
#  'Beans, Dry, Pinto, 657 (0% moisture)',
#  'Beans, Dry, Pinto, 456 (0% moisture)',
#  'Beans, Dry, Pinto, 700 (0% moisture)',
#  'Beans, Dry, Pinto, 394 (0% moisture)',
#  'Beans, Dry, Pinto, 735 (0% moisture)',
#  'Beans, Dry, Pinto, 391 (0% moisture)',
#  'Beans, Dry, Pinto, 702 (0% moisture)',
#  'Beans, Dry, Pinto, 361 (0% moisture)',
#  'Beans, Dry, Pinto, 747 (0% moisture)',
#  'Beans, Dry, Pinto, 358 (0% moisture)',
#  'Beans, Dry, Pinto, 720 (0% moisture)',
#  'Beans, Dry, Pinto, 398 (0% moisture)',
#  'Beans, Dry, Pinto, 765 (0% moisture)',
#  'Beans, Dry, Pinto, 516 (0% moisture)',
#  'Beans, Dry, Pinto, 776 (0% moisture)',
#  'Beans, Dry, Pinto, 389 (0% moisture)',
#  'Beans, Dry, Pinto, 736 (0% moisture)',
#  'Beans, Dry, Pinto, 452 (0% moisture)',
#  'Beans, Dry, Pinto, 728 (0% moisture)',
#  'Beans, Dry, Pinto, 497 (0% moisture)',
#  'Beans, Dry, Pinto, 715 (0% moisture)',
#  'Beans, Dry, Pinto, 373 (0% moisture)',
#  'Beans, Dry, Pinto, 821 (0% moisture)',
#  'Beans, Dry, Pinto, 479 (0% moisture)',
#  'Beans, Dry, Pinto, 734 (0% moisture)',
#  'Beans, Dry, Pinto, 368 (0% moisture)',
#  'Beans, Dry, Pinto, 640 (0% moisture)',
#  'Beans, Dry, Pinto, 510 (0% moisture)',
#  'Beans, Dry, Pinto, 718 (0% moisture)',
#  'Beans, Dry, Pinto, 426 (0% moisture)',
#  'Beans, Dry, Pinto, 783 (0% moisture)',
#  'Beans, Dry, Pinto, 498 (0% moisture)',
#  'Beans, Dry, Pinto, 634 (0% moisture)',
#  'Beans, Dry, Pinto, 427 (0% moisture)',
#  'Beans, Dry, Pinto, 695 (0% moisture)',
#  'Beans, Dry, Pinto, 382 (0% moisture)',
#  'Beans, Dry, Pinto, 661 (0% moisture)',
#  'Beans, Dry, Pinto, 464 (0% moisture)',
#  'Beans, Dry, Pinto, 770 (0% moisture)',
#  'Beans, Dry, Pinto, 455 (0% moisture)',
#  'Beans, Dry, Pinto, 639 (0% moisture)',
#  'Beans, Dry, Pinto, 469 (0% moisture)',
#  'Beans, Dry, Pinto, 758 (0% moisture)',
#  'Beans, Dry, Pinto, 355 (0% moisture)',
#  'Beans, Dry, Pinto, 632 (0% moisture)',
#  'Beans, Dry, Pinto, 511 (0% moisture)',
#  'Beans, Dry, Pinto, 815 (0% moisture)',
#  'Beans, Dry, Pinto, 325 (0% moisture)',
#  'Beans, Dry, Pinto, 751 (0% moisture)',
#  'Beans, Dry, Pinto, 349 (0% moisture)',
#  'Beans, Dry, Pinto, 714 (0% moisture)',
#  'Beans, Dry, Pinto, 408 (0% moisture)',
#  'Beans, Dry, Pinto, 711 (0% moisture)',
#  'Beans, Dry, Pinto, 480 (0% moisture)',
#  'Beans, Dry, Pinto, 808 (0% moisture)',
#  'Beans, Dry, Pinto, 499 (0% moisture)',
#  'Beans, Dry, Pinto, 710 (0% moisture)',
#  'Beans, Dry, Pinto, 343 (0% moisture)',
#  'Beans, Dry, Pinto, 764 (0% moisture)',
#  'Beans, Dry, Pinto, 468 (0% moisture)',
#  'Beans, Dry, Pinto, 773 (0% moisture)',
#  'Beans, Dry, Pinto, 371 (0% moisture)',
#  'Beans, Dry, Pinto, 669 (0% moisture)',
#  'Beans, Dry, Pinto, 421 (0% moisture)',
#  'Beans, Dry, Pinto, 663 (0% moisture)',
#  'Beans, Dry, Pinto, 340 (0% moisture)',
#  'Beans, Dry, Pinto, 704 (0% moisture)',
#  'Beans, Dry, Pinto, 362 (0% moisture)',
#  'Beans, Dry, Pinto, 665 (0% moisture)',
#  'Beans, Dry, Pinto, 432 (0% moisture)',
#  'Beans, Dry, Pinto, 787 (0% moisture)',
#  'Beans, Dry, Pinto, 336 (0% moisture)',
#  'Beans, Dry, Pinto, 793 (0% moisture)',
#  'Beans, Dry, Pinto, 466 (0% moisture)',
#  'Beans, Dry, Pinto, 820 (0% moisture)',
#  'Beans, Dry, Pinto, 450 (0% moisture)',
#  'Beans, Dry, Pinto, 801 (0% moisture)',
#  'Beans, Dry, Pinto, 484 (0% moisture)',
#  'Beans, Dry, Pinto, 729 (0% moisture)',
#  'Beans, Dry, Pinto, 322 (0% moisture)',
#  'Beans, Dry, Pinto, 678 (0% moisture)',
#  'Beans, Dry, Pinto, 494 (0% moisture)',
#  'Beans, Dry, Pinto, 809 (0% moisture)',
#  'Beans, Dry, Pinto, 496 (0% moisture)',
#  'Beans, Dry, Pinto, 727 (0% moisture)',
#  'Beans, Dry, Pinto, 482 (0% moisture)',
#  'Beans, Dry, Pinto, 647 (0% moisture)',
#  'Beans, Dry, Pinto, 513 (0% moisture)',
#  'Beans, Dry, Pinto, 660 (0% moisture)',
#  'Beans, Dry, Pinto, 489 (0% moisture)',
#  'Beans, Dry, Pinto, 738 (0% moisture)',
#  'Beans, Dry, Pinto, 492 (0% moisture)',
#  'Beans, Dry, Pinto, 650 (0% moisture)',
#  'Beans, Dry, Pinto, 463 (0% moisture)',
#  'Beans, Dry, Pinto, 653 (0% moisture)',
#  'Beans, Dry, Pinto, 440 (0% moisture)',
#  'Beans, Dry, Pinto, 709 (0% moisture)',
#  'Beans, Dry, Pinto, 517 (0% moisture)',
#  'Beans, Dry, Pinto, 724 (0% moisture)',
#  'Beans, Dry, Pinto, 454 (0% moisture)',
#  'Beans, Dry, Pinto, 812 (0% moisture)',
#  'Beans, Dry, Pinto, 353 (0% moisture)',
#  'Beans, Dry, Pinto, 692 (0% moisture)',
#  'Beans, Dry, Pinto, 506 (0% moisture)',
#  'Beans, Dry, Pinto, 642 (0% moisture)',
#  'Beans, Dry, Pinto, 420 (0% moisture)',
#  'Beans, Dry, Pinto, 795 (0% moisture)',
#  'Beans, Dry, Pinto, 224 (0% moisture)',
#  'Beans, Dry, Pinto, 413 (0% moisture)',
#  'Beans, Dry, Pinto, 621 (0% moisture)',
#  'Beans, Dry, Pinto, 744 (0% moisture)',
#  'Beans, Dry, Pinto, 451 (0% moisture)',
#  'Beans, Dry, Pinto, 691 (0% moisture)',
#  'Beans, Dry, Pinto, 512 (0% moisture)',
#  'Beans, Dry, Pinto, 749 (0% moisture)',
#  'Beans, Dry, Pinto, 388 (0% moisture)',
#  'Beans, Dry, Pinto, 659 (0% moisture)',
#  'Beans, Dry, Pinto, 352 (0% moisture)',
#  'Beans, Dry, Pinto, 802 (0% moisture)',
#  'Beans, Dry, Pinto, 416 (0% moisture)',
#  'Beans, Dry, Pinto, 754 (0% moisture)',
#  'Beans, Dry, Pinto, 333 (0% moisture)',
#  'Beans, Dry, Pinto, 643 (0% moisture)',
#  'Beans, Dry, Pinto, 425 (0% moisture)',
#  'Beans, Dry, Pinto, 708 (0% moisture)',
#  'Beans, Dry, Pinto, 367 (0% moisture)',
#  'Beans, Dry, Pinto, 807 (0% moisture)',
#  'Beans, Dry, Pinto, 324 (0% moisture)',
#  'Beans, Dry, Pinto, 668 (0% moisture)',
#  'Beans, Dry, Pinto, 397 (0% moisture)',
#  'Beans, Dry, Pinto, 733 (0% moisture)',
#  'Beans, Dry, Pinto, 414 (0% moisture)',
#  'Beans, Dry, Pinto, 671 (0% moisture)',
#  'Beans, Dry, Pinto, 428 (0% moisture)',
#  'Beans, Dry, Pinto, 681 (0% moisture)',
#  'Beans, Dry, Pinto, 459 (0% moisture)',
#  'Beans, Dry, Pinto, 775 (0% moisture)',
#  'Beans, Dry, Pinto, 390 (0% moisture)',
#  'Beans, Dry, Pinto, 631 (0% moisture)',
#  'Beans, Dry, Pinto, 410 (0% moisture)',
#  'Beans, Dry, Pinto, 782 (0% moisture)',
#  'Beans, Dry, Pinto, 381 (0% moisture)',
#  'Beans, Dry, Pinto, 781 (0% moisture)',
#  'Beans, Dry, Pinto, 515 (0% moisture)',
#  'Beans, Dry, Pinto, 740 (0% moisture)',
#  'Beans, Dry, Pinto, 383 (0% moisture)',
#  'Beans, Dry, Pinto, 810 (0% moisture)',
#  'Beans, Dry, Pinto, 520 (0% moisture)',
#  'Beans, Dry, Pinto, 686 (0% moisture)',
#  'Beans, Dry, Pinto, 372 (0% moisture)',
#  'Beans, Dry, Pinto, 791 (0% moisture)',
#  'Beans, Dry, Pinto, 475 (0% moisture)',
#  'Beans, Dry, Pinto, 677 (0% moisture)',
#  'Beans, Dry, Pinto, 329 (0% moisture)',
#  'Beans, Dry, Pinto, 682 (0% moisture)',
#  'Beans, Dry, Pinto, 393 (0% moisture)',
#  'Beans, Dry, Pinto, 705 (0% moisture)',
#  'Beans, Dry, Pinto, 328 (0% moisture)',
#  'Beans, Dry, Pinto, 630 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8014 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8142 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8021 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8111 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8009 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8153 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8017 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8169 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8073 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8154 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8011 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8115 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8050 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8161 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8033 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8199 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8056 (0% moisture)',
#  'Beans, Dry, Small Red, 11F-8137 (0% moisture)',
#  'Beans, Dry, Small Red, 400 (0% moisture)',
#  'Beans, Dry, Small Red, 772 (0% moisture)',
#  'Beans, Dry, Small Red, 470 (0% moisture)',
#  'Beans, Dry, Small Red, 798 (0% moisture)',
#  'Beans, Dry, Small Red, 431 (0% moisture)',
#  'Beans, Dry, Small Red, 813 (0% moisture)',
#  'Beans, Dry, Small Red, 505 (0% moisture)',
#  'Beans, Dry, Small Red, 731 (0% moisture)',
#  'Beans, Dry, Small Red, 509 (0% moisture)',
#  'Beans, Dry, Small Red, 690 (0% moisture)',
#  'Beans, Dry, Small Red, 500 (0% moisture)',
#  'Beans, Dry, Small Red, 769 (0% moisture)',
#  'Beans, Dry, Small Red, 417 (0% moisture)',
#  'Beans, Dry, Small Red, 674 (0% moisture)',
#  'Beans, Dry, Small Red, 409 (0% moisture)',
#  'Beans, Dry, Small Red, 806 (0% moisture)',
#  'Beans, Dry, Small Red, 419 (0% moisture)',
#  'Beans, Dry, Small Red, 799 (0% moisture)',
#  'Beans, Dry, Small Red, 344 (0% moisture)',
#  'Beans, Dry, Small Red, 698 (0% moisture)',
#  'Beans, Dry, Small Red, 376 (0% moisture)',
#  'Beans, Dry, Small Red, 685 (0% moisture)',
#  'Beans, Dry, Small Red, 491 (0% moisture)',
#  'Beans, Dry, Small Red, 673 (0% moisture)',
#  'Beans, Dry, Small Red, 357 (0% moisture)',
#  'Beans, Dry, Small Red, 760 (0% moisture)',
#  'Beans, Dry, Small Red, 240 (0% moisture)',
#  'Beans, Dry, Small Red, 330 (0% moisture)',
#  'Beans, Dry, Small Red, 606 (0% moisture)',
#  'Beans, Dry, Small Red, 797 (0% moisture)',
#  'Beans, Dry, Small Red, 488 (0% moisture)',
#  'Beans, Dry, Small Red, 722 (0% moisture)',
#  'Beans, Dry, Small Red, 473 (0% moisture)',
#  'Beans, Dry, Small Red, 804 (0% moisture)',
#  'Beans, Dry, Small Red, 405 (0% moisture)',
#  'Beans, Dry, Small Red, 755 (0% moisture)',
#  'Beans, Dry, Small Red, 487 (0% moisture)',
#  'Beans, Dry, Small Red, 646 (0% moisture)',
#  'Beans, Dry, Small Red, 508 (0% moisture)',
#  'Beans, Dry, Small Red, 670 (0% moisture)',
#  'Beans, Dry, Small Red, 374 (0% moisture)',
#  'Beans, Dry, Small Red, 746 (0% moisture)',
#  'Beans, Dry, Small Red, 370 (0% moisture)',
#  'Beans, Dry, Small Red, 786 (0% moisture)',
#  'Beans, Dry, Small Red, 347 (0% moisture)',
#  'Beans, Dry, Small Red, 649 (0% moisture)',
#  'Beans, Dry, Small Red, 403 (0% moisture)',
#  'Beans, Dry, Small Red, 759 (0% moisture)',
#  'Beans, Dry, Small Red, 332 (0% moisture)',
#  'Beans, Dry, Small Red, 635 (0% moisture)',
#  'Beans, Dry, Small Red, 493 (0% moisture)',
#  'Beans, Dry, Small Red, 811 (0% moisture)',
#  'Beans, Dry, Small Red, 439 (0% moisture)',
#  'Beans, Dry, Small Red, 774 (0% moisture)',
#  'Beans, Dry, Small Red, 369 (0% moisture)',
#  'Beans, Dry, Small Red, 785 (0% moisture)',
#  'Beans, Dry, Small Red, 471 (0% moisture)',
#  'Beans, Dry, Small Red, 757 (0% moisture)',
#  'Beans, Dry, Small Red, 323 (0% moisture)',
#  'Beans, Dry, Small Red, 703 (0% moisture)',
#  'Beans, Dry, Medium Red, 490 (0% moisture)',
#  'Beans, Dry, Medium Red, 756 (0% moisture)',
#  'Beans, Dry, Cranberry, 11F-8022 (0% moisture)',
#  'Beans, Dry, Cranberry, 11F-8131 (0% moisture)',
#  'Beans, Dry, Cranberry, 378 (0% moisture)',
#  'Beans, Dry, Cranberry, 750 (0% moisture)',
#  'Beans, Dry, Light Tan, 11F-8086 (0% moisture)',
#  'Beans, Dry, Light Tan, 11F-8174 (0% moisture)',
#  'Beans, Dry, Black, 11F-8045 (0% moisture)',
#  'Beans, Dry, Black, 11F-8177 (0% moisture)',
#  'Beans, Dry, Black, 11F-8036 (0% moisture)',
#  'Beans, Dry, Black, 11F-8122 (0% moisture)',
#  'Beans, Dry, Black, 11F-8003 (0% moisture)',
#  'Beans, Dry, Black, 11F-8117 (0% moisture)',
#  'Beans, Dry, Black, 11F-8016 (0% moisture)',
#  'Beans, Dry, Black, 11F-8112 (0% moisture)',
#  'Beans, Dry, Black, 11F-8013 (0% moisture)',
#  'Beans, Dry, Black, 11F-8180 (0% moisture)',
#  'Beans, Dry, Black, 11F-8039 (0% moisture)',
#  'Beans, Dry, Black, 11F-8116 (0% moisture)',
#  'Beans, Dry, Black, 11F-8023 (0% moisture)',
#  'Beans, Dry, Black, 11F-8168 (0% moisture)',
#  'Beans, Dry, Black, 11F-8062 (0% moisture)',
#  'Beans, Dry, Black, 11F-8150 (0% moisture)',
#  'Beans, Dry, Black, 11F-8046 (0% moisture)',
#  'Beans, Dry, Black, 11F-8146 (0% moisture)',
#  'Beans, Dry, Black, 11F-8000 (0% moisture)',
#  'Beans, Dry, Black, 11F-8129 (0% moisture)',
#  'Beans, Dry, Black, 11F-8044 (0% moisture)',
#  'Beans, Dry, Black, 11F-8158 (0% moisture)',
#  'Beans, Dry, Black, 11F-8029 (0% moisture)',
#  'Beans, Dry, Black, 11F-8119 (0% moisture)',
#  'Beans, Dry, Black, 11F-8002 (0% moisture)',
#  'Beans, Dry, Black, 11F-8135 (0% moisture)',
#  'Beans, Dry, Black, 11F-8020 (0% moisture)',
#  'Beans, Dry, Black, 11F-8140 (0% moisture)',
#  'Beans, Dry, Black, 11F-8015 (0% moisture)',
#  'Beans, Dry, Black, 11F-8123 (0% moisture)',
#  'Beans, Dry, Black, 348 (0% moisture)',
#  'Beans, Dry, Black, 737 (0% moisture)',
#  'Beans, Dry, Black, 298 (0% moisture)',
#  'Beans, Dry, Black, 533 (0% moisture)',
#  'Beans, Dry, Black, 331 (0% moisture)',
#  'Beans, Dry, Black, 745 (0% moisture)',
#  'Beans, Dry, Black, 244 (0% moisture)',
#  'Beans, Dry, Black, 604 (0% moisture)',
#  'Beans, Dry, Black, 250 (0% moisture)',
#  'Beans, Dry, Black, 583 (0% moisture)',
#  'Beans, Dry, Black, 269 (0% moisture)',
#  'Beans, Dry, Black, 566 (0% moisture)',
#  'Beans, Dry, Black, 296 (0% moisture)',
#  'Beans, Dry, Black, 611 (0% moisture)',
#  'Beans, Dry, Black, 276 (0% moisture)',
#  'Beans, Dry, Black, 624 (0% moisture)',
#  'Beans, Dry, Black, 303 (0% moisture)',
#  'Beans, Dry, Black, 617 (0% moisture)',
#  'Beans, Dry, Black, 221 (0% moisture)',
#  'Beans, Dry, Black, 602 (0% moisture)',
#  'Beans, Dry, Black, 305 (0% moisture)',
#  'Beans, Dry, Black, 553 (0% moisture)',
#  'Beans, Dry, Black, 304 (0% moisture)',
#  'Beans, Dry, Black, 601 (0% moisture)',
#  'Beans, Dry, Black, 274 (0% moisture)',
#  'Beans, Dry, Black, 526 (0% moisture)',
#  'Beans, Dry, Black, 232 (0% moisture)',
#  'Beans, Dry, Black, 534 (0% moisture)',
#  'Beans, Dry, Black, 219 (0% moisture)',
#  'Beans, Dry, Black, 580 (0% moisture)',
#  'Beans, Dry, Black, 254 (0% moisture)',
#  'Beans, Dry, Black, 542 (0% moisture)',
#  'Beans, Dry, Black, 424 (0% moisture)',
#  'Beans, Dry, Black, 267 (0% moisture)',
#  'Beans, Dry, Black, 767 (0% moisture)',
#  'Beans, Dry, Black, 569 (0% moisture)',
#  'Beans, Dry, Black, 249 (0% moisture)',
#  'Beans, Dry, Black, 590 (0% moisture)',
#  'Beans, Dry, Black, 282 (0% moisture)',
#  'Beans, Dry, Black, 597 (0% moisture)',
#  'Beans, Dry, Black, 247 (0% moisture)',
#  'Beans, Dry, Black, 619 (0% moisture)',
#  'Beans, Dry, Black, 222 (0% moisture)',
#  'Beans, Dry, Black, 608 (0% moisture)',
#  'Beans, Dry, Black, 225 (0% moisture)',
#  'Beans, Dry, Black, 573 (0% moisture)',
#  'Beans, Dry, Black, 248 (0% moisture)',
#  'Beans, Dry, Black, 607 (0% moisture)',
#  'Beans, Dry, Black, 223 (0% moisture)',
#  'Beans, Dry, Black, 522 (0% moisture)',
#  'Beans, Dry, Black, 314 (0% moisture)',
#  'Beans, Dry, Black, 531 (0% moisture)',
#  'Beans, Dry, Black, 215 (0% moisture)',
#  'Beans, Dry, Black, 615 (0% moisture)',
#  'Beans, Dry, Black, 310 (0% moisture)',
#  'Beans, Dry, Black, 536 (0% moisture)',
#  'Beans, Dry, Black, 318 (0% moisture)',
#  'Beans, Dry, Black, 537 (0% moisture)',
#  'Beans, Dry, Black, 271 (0% moisture)',
#  'Beans, Dry, Black, 545 (0% moisture)',
#  'Beans, Dry, Black, 278 (0% moisture)',
#  'Beans, Dry, Black, 552 (0% moisture)',
#  'Beans, Dry, Black, 266 (0% moisture)',
#  'Beans, Dry, Black, 550 (0% moisture)',
#  'Beans, Dry, Black, 288 (0% moisture)',
#  'Beans, Dry, Black, 572 (0% moisture)',
#  'Beans, Dry, Black, 301 (0% moisture)',
#  'Beans, Dry, Black, 575 (0% moisture)',
#  'Beans, Dry, Black, 259 (0% moisture)',
#  'Beans, Dry, Black, 610 (0% moisture)',
#  'Beans, Dry, Black, 395 (0% moisture)',
#  'Beans, Dry, Black, 258 (0% moisture)',
#  'Beans, Dry, Black, 707 (0% moisture)',
#  'Beans, Dry, Black, 562 (0% moisture)',
#  'Beans, Dry, Black, 227 (0% moisture)',
#  'Beans, Dry, Black, 620 (0% moisture)',
#  'Beans, Dry, Black, 214 (0% moisture)',
#  'Beans, Dry, Black, 547 (0% moisture)',
#  'Beans, Dry, Black, 263 (0% moisture)',
#  'Beans, Dry, Black, 570 (0% moisture)',
#  'Beans, Dry, Black, 251 (0% moisture)',
#  'Beans, Dry, Black, 592 (0% moisture)',
#  'Beans, Dry, Black, 238 (0% moisture)',
#  'Beans, Dry, Black, 528 (0% moisture)',
#  'Beans, Dry, Black, 273 (0% moisture)',
#  'Beans, Dry, Black, 529 (0% moisture)',
#  'Beans, Dry, Black, 472 (0% moisture)',
#  'Beans, Dry, Black, 753 (0% moisture)',
#  'Beans, Dry, Black, 286 (0% moisture)',
#  'Beans, Dry, Black, 596 (0% moisture)',
#  'Beans, Dry, Black, 297 (0% moisture)',
#  'Beans, Dry, Black, 600 (0% moisture)',
#  'Beans, Dry, Black, 317 (0% moisture)',
#  'Beans, Dry, Black, 625 (0% moisture)',
#  'Beans, Dry, Black, 291 (0% moisture)',
#  'Beans, Dry, Black, 574 (0% moisture)',
#  'Beans, Dry, Small White, 11F-8057 (0% moisture)',
#  'Beans, Dry, Small White, 11F-8160 (0% moisture)',
#  'Beans, Dry, Small White, 239 (0% moisture)',
#  'Beans, Dry, Small White, 571 (0% moisture)',
#  'Beans, Dry, Small White, 272 (0% moisture)',
#  'Beans, Dry, Small White, 618 (0% moisture)',
#  'Beans, Dry, Small White, 265 (0% moisture)',
#  'Beans, Dry, Small White, 527 (0% moisture)',
#  'Beans, Dry, Small White, 309 (0% moisture)',
#  'Beans, Dry, Small White, 549 (0% moisture)',
#  'Beans, Dry, Small White, 285 (0% moisture)',
#  'Beans, Dry, Small White, 544 (0% moisture)',
#  'Beans, Dry, Small White, 275 (0% moisture)',
#  'Beans, Dry, Small White, 564 (0% moisture)',
#  'Beans, Dry, Red, 345 (0% moisture)',
#  'Beans, Dry, Red, 645 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8063 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8128 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8163 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8087 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8145 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8025 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8141 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8097 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8194 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8053 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8155 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8052 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8134 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8051 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8113 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8093 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8110 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8060 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8184 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8090 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8152 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8085 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8192 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8010 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8185 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8068 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8172 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8067 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8125 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8008 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8171 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8092 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8138 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8077 (0% moisture)',
#  'Beans, Dry, Great Northern, 11F-8139 (0% moisture)',
#  'Beans, Dry, Great Northern, 441 (0% moisture)',
#  'Beans, Dry, Great Northern, 648 (0% moisture)',
#  'Beans, Dry, Great Northern, 446 (0% moisture)',
#  'Beans, Dry, Great Northern, 726 (0% moisture)',
#  'Beans, Dry, Great Northern, 235 (0% moisture)',
#  'Beans, Dry, Great Northern, 579 (0% moisture)',
#  'Beans, Dry, Great Northern, 306 (0% moisture)',
#  'Beans, Dry, Great Northern, 594 (0% moisture)',
#  'Beans, Dry, Great Northern, 423 (0% moisture)',
#  'Beans, Dry, Great Northern, 651 (0% moisture)',
#  'Beans, Dry, Great Northern, 315 (0% moisture)',
#  'Beans, Dry, Great Northern, 581 (0% moisture)',
#  'Beans, Dry, Great Northern, 396 (0% moisture)',
#  'Beans, Dry, Great Northern, 778 (0% moisture)',
#  'Beans, Dry, Great Northern, 406 (0% moisture)',
#  'Beans, Dry, Great Northern, 688 (0% moisture)',
#  'Beans, Dry, Great Northern, 384 (0% moisture)',
#  'Beans, Dry, Great Northern, 644 (0% moisture)',
#  'Beans, Dry, Great Northern, 380 (0% moisture)',
#  'Beans, Dry, Great Northern, 748 (0% moisture)',
#  'Beans, Dry, Great Northern, 392 (0% moisture)',
#  'Beans, Dry, Great Northern, 658 (0% moisture)',
#  'Beans, Dry, Great Northern, 363 (0% moisture)',
#  'Beans, Dry, Great Northern, 792 (0% moisture)',
#  'Beans, Dry, Great Northern, 339 (0% moisture)',
#  'Beans, Dry, Great Northern, 713 (0% moisture)',
#  'Beans, Dry, Great Northern, 346 (0% moisture)',
#  'Beans, Dry, Great Northern, 780 (0% moisture)',
#  'Beans, Dry, Great Northern, 460 (0% moisture)',
#  'Beans, Dry, Great Northern, 672 (0% moisture)',
#  'Beans, Dry, Great Northern, 385 (0% moisture)',
#  'Beans, Dry, Great Northern, 788 (0% moisture)',
#  'Beans, Dry, Great Northern, 429 (0% moisture)',
#  'Beans, Dry, Great Northern, 789 (0% moisture)',
#  'Beans, Dry, Great Northern, 514 (0% moisture)',
#  'Beans, Dry, Great Northern, 730 (0% moisture)',
#  'Beans, Dry, Great Northern, 501 (0% moisture)',
#  'Beans, Dry, Great Northern, 638 (0% moisture)',
#  'Beans, Dry, Great Northern, 474 (0% moisture)',
#  'Beans, Dry, Great Northern, 790 (0% moisture)',
#  'Beans, Dry, Great Northern, 402 (0% moisture)',
#  'Beans, Dry, Great Northern, 822 (0% moisture)',
#  'Beans, Dry, Great Northern, 350 (0% moisture)',
#  'Beans, Dry, Great Northern, 828 (0% moisture)',
#  'Beans, Dry, Great Northern, 375 (0% moisture)',
#  'Beans, Dry, Great Northern, 662 (0% moisture)',
#  'Beans, Dry, Great Northern, 337 (0% moisture)',
#  'Beans, Dry, Great Northern, 656 (0% moisture)',
#  'Beans, Dry, Great Northern, 467 (0% moisture)',
#  'Beans, Dry, Great Northern, 824 (0% moisture)',
#  'Beans, Dry, Great Northern, 507 (0% moisture)',
#  'Beans, Dry, Great Northern, 826 (0% moisture)',
#  'Beans, Dry, Great Northern, 327 (0% moisture)',
#  'Beans, Dry, Great Northern, 675 (0% moisture)',
#  'Beans, Dry, Great Northern, 401 (0% moisture)',
#  'Beans, Dry, Great Northern, 742 (0% moisture)',
#  'Beans, Dry, Great Northern, 518 (0% moisture)',
#  'Beans, Dry, Great Northern, 666 (0% moisture)',
#  'Beans, Dry, Great Northern, 457 (0% moisture)',
#  'Beans, Dry, Great Northern, 818 (0% moisture)',
#  'Beans, Dry, Great Northern, 293 (0% moisture)',
#  'Beans, Dry, Great Northern, 412 (0% moisture)',
#  'Beans, Dry, Great Northern, 616 (0% moisture)',
#  'Beans, Dry, Great Northern, 689 (0% moisture)',
#  'Beans, Dry, Great Northern, 387 (0% moisture)',
#  'Beans, Dry, Great Northern, 766 (0% moisture)',
#  'Beans, Dry, Great Northern, 519 (0% moisture)',
#  'Beans, Dry, Great Northern, 768 (0% moisture)',
#  'Beans, Dry, Great Northern, 418 (0% moisture)',
#  'Beans, Dry, Great Northern, 637 (0% moisture)',
#  'Beans, Dry, Great Northern, 495 (0% moisture)',
#  'Beans, Dry, Great Northern, 680 (0% moisture)',
#  'Beans, Dry, Great Northern, 335 (0% moisture)',
#  'Beans, Dry, Great Northern, 763 (0% moisture)',
#  'Beans, Dry, Great Northern, 364 (0% moisture)',
#  'Beans, Dry, Great Northern, 683 (0% moisture)',
#  'Beans, Dry, Great Northern, 379 (0% moisture)',
#  'Beans, Dry, Great Northern, 655 (0% moisture)',
#  'Beans, Dry, Great Northern, 434 (0% moisture)',
#  'Beans, Dry, Great Northern, 716 (0% moisture)',
#  'Beans, Dry, Great Northern, 341 (0% moisture)',
#  'Beans, Dry, Great Northern, 697 (0% moisture)',
#  'Beans, Dry, Great Northern, 438 (0% moisture)',
#  'Beans, Dry, Great Northern, 706 (0% moisture)',
#  'Beans, Dry, Great Northern, 449 (0% moisture)',
#  'Beans, Dry, Great Northern, 741 (0% moisture)',
#  'Beans, Dry, Great Northern, 407 (0% moisture)',
#  'Beans, Dry, Great Northern, 723 (0% moisture)',
#  'Beans, Dry, Great Northern, 447 (0% moisture)',
#  'Beans, Dry, Great Northern, 827 (0% moisture)',
#  'Beans, Dry, Great Northern, 458 (0% moisture)',
#  'Beans, Dry, Great Northern, 693 (0% moisture)',
#  'Beans, Dry, Great Northern, 415 (0% moisture)',
#  'Beans, Dry, Great Northern, 762 (0% moisture)',
#  'Beans, Dry, Great Northern, 453 (0% moisture)',
#  'Beans, Dry, Great Northern, 777 (0% moisture)',
#  'Beans, Dry, Great Northern, 485 (0% moisture)',
#  'Beans, Dry, Great Northern, 800 (0% moisture)',
#  'Beans, Dry, Great Northern, 444 (0% moisture)',
#  'Beans, Dry, Great Northern, 694 (0% moisture)']

# %% [markdown]
# #Exploring the description column

# %%
#new_df = df['description'].drop_duplicates(subset('description'))
#new_df
df_sample_food_only = df.loc[df['data_type'] == 'sample_food'].copy()
df_sample_food_only_count = df.loc[df['data_type'] == 'sample_food'].count()
print("Number of unique food samples")
print(df_sample_food_only_count)

print("Number of unique food samples with unique descriptions")
df_sample_food_only['description'].unique().tolist();
# Out:
# Number of unique food samples
# fdc_id              1828
# data_type           1828
# description         1828
# food_category_id    1813
# publication_date    1828
# dtype: int64
# Number of unique food samples with unique descriptions

# %%
#how to search for particulat string, good source is here https://medium.com/factory-mind/regex-tutorial-a-simple-cheatsheet-by-examples-649dc1c3f285
new_df = df[df['description'].str.contains('^chicken', case=False, regex=True) & df['data_type'].str.contains('^sample_food') & df['description'].str.contains("\d", regex=True)].copy()
new_df.drop_duplicates(subset=['description'], inplace=True)
new_df;

# %% [markdown]
# # Exploring the different columns in database

# %% [markdown]
# The goal is to have a json formatted database of ingredients, that isn't cluttered by information users don't need

# %%
df['data_type'].unique()
# Out:
# array(['sample_food', 'market_acquisition', 'sub_sample_food',
#        'foundation_food', 'agricultural_acquisition'], dtype=object)

# %%
#confirming that all the food have at least sample_food and foundational_food
df[(df['data_type']=='sample_food') | (df['data_type'] == 'foundation_food')]

unique_agri = df[(df['data_type']=='agricultural_acquisition')]
unique_agri_descriptions = unique_agri['description'].unique().tolist()

unique_market = df[(df['data_type']=='market_acquisition')]
unique_market_descriptions = unique_market['description'].unique().tolist()

unique_foundation_food = df[(df['data_type']=='foundation_food')]
unique_foundation_food_descriptions = unique_foundation_food['description'].unique().tolist()

unique_sample_food = df[(df['data_type']=='sample_food')]
unique_sample_food_descriptions = unique_sample_food['description'].unique().tolist()
#df[df['data_type'] == 'foundation_food'];
len(np.setdiff1d(unique_agri_descriptions, unique_market_descriptions))
# Out:
# 805

# %%
df_without_sub_sample_food = df[~(df['data_type'] == 'sub_sample_food')].copy()
df_without_sub_sample_food_no_dup = df_without_sub_sample_food.drop_duplicates(subset=['data_type','description'])
df_without_sub_sample_food_no_dup.sort_values(by=['description'])
df_without_sub_sample_food_no_dup['food_category_id'].unique()
# Out:
# array([16.,  1., 13., 11.,  2.,  7., 12.,  6.,  9., 18.,  4.,  5., 15.,
#        19., 25., 10., nan, 20.])

# %% [markdown]
# new_df = df[df['data_type'].str.contains('^sample_food')].copy()
# new_df.drop_duplicates(subset=['description'], inplace=True)
# new_df;

# %% [markdown]
# ## Conclusions from Foundation Food DB
# From this particular DB, we should be only using foundation_foods, as they are averaged versions of all the other samples and market acquisitions. Market acquisitions are sometimes put together to make one sample_foods and then based on that sample_food foundation_food is made. I didn't find ingredients so far that wouldn't fit that.
#
# You can experiment yourself using the code below. It prints very nicely the given category.

# %%
# we can simply use foundation in this case. Each of the sample_foods 
df_cleaned_cat1 = df_without_sub_sample_food_no_dup[df_without_sub_sample_food_no_dup['food_category_id'] == 4]
#df_cleaned_cat1_foundation_only = df_cleaned_cat1[df_cleaned_cat1['data_type'] == 'foundation_food']
#df_cleaned_cat1_foundation_only.count()
df_cleaned_cat1
# Out:
#        fdc_id           data_type  ... food_category_id  publication_date
# 9709   330416         sample_food  ...              4.0        2019-04-01
# 9710   330417  market_acquisition  ...              4.0        2019-04-01
# 9711   330418  market_acquisition  ...              4.0        2019-04-01
# 9714   330421         sample_food  ...              4.0        2019-04-01
# 9715   330422  market_acquisition  ...              4.0        2019-04-01
# 9716   330423  market_acquisition  ...              4.0        2019-04-01
# 9719   330426         sample_food  ...              4.0        2019-04-01
# 9720   330427  market_acquisition  ...              4.0        2019-04-01
# 9721   330428  market_acquisition  ...              4.0        2019-04-01
# 9722   330429  market_acquisition  ...              4.0        2019-04-01
# 9726   330433         sample_food  ...              4.0        2019-04-01
# 9727   330434  market_acquisition  ...              4.0        2019-04-01
# 9728   330435  market_acquisition  ...              4.0        2019-04-01
# 9729   330436  market_acquisition  ...              4.0        2019-04-01
# 9734   330441         sample_food  ...              4.0        2019-04-01
# 9735   330442  market_acquisition  ...              4.0        2019-04-01
# 9736   330443  market_acquisition  ...              4.0        2019-04-01
# 9737   330444  market_acquisition  ...              4.0        2019-04-01
# 9743   330450         sample_food  ...              4.0        2019-04-01
# 9744   330451  market_acquisition  ...              4.0        2019-04-01
# 9745   330452  market_acquisition  ...              4.0        2019-04-01
# 9746   330453  market_acquisition  ...              4.0        2019-04-01
# 9751   330458     foundation_food  ...              4.0        2019-04-01
# 16840  748237         sample_food  ...              4.0        2019-12-16
# 16841  748238  market_acquisition  ...              4.0        2019-12-16
# 16881  748278     foundation_food  ...              4.0        2019-12-16
# 16882  748279         sample_food  ...              4.0        2019-12-16
# 16883  748280  market_acquisition  ...              4.0        2019-12-16
# 16926  748323     foundation_food  ...              4.0        2019-12-16
# 16927  748324         sample_food  ...              4.0        2019-12-16
# 16928  748325  market_acquisition  ...              4.0        2019-12-16
# 16969  748366     foundation_food  ...              4.0        2019-12-16
# 16970  748367         sample_food  ...              4.0        2019-12-16
# 16971  748368  market_acquisition  ...              4.0        2019-12-16
# 17211  748608     foundation_food  ...              4.0        2019-12-16
#
# [35 rows x 5 columns]

# %% [markdown]
# # Exploring SR Legacy DB

# %%
sr_data = sr_legacy_data.copy()

# %% [markdown]
# So, it turned out that all the all caps words (apart from USDA) were were actually names of brands. Excluding them

# %%
print(sr_data.columns)
sr_data.sort_values(by='description')
usda_only = sr_data[sr_data['description'].str.contains('USDA')]
sr_data_cleaned = sr_data[~(sr_data['description'].str.contains("[A-Z]{2,}", regex=True))].sort_values(by='description')
sr_data_cleaned.head()
for_compare = sr_data[(sr_data['description'].str.contains("[A-Z]{2,}", regex=True))].sort_values(by='description')
#all good, but exlude USDA
# Out:
# Index(['fdc_id', 'data_type', 'description', 'food_category_id',
#        'publication_date'],
#       dtype='object')

# %% [markdown]
# # Starting to transform Dataframe to final result

# %%
# !pip install --upgrade gupload
# Out:
# Requirement already satisfied: gupload in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: click==7.0 in /usr/local/lib/python3.7/dist-packages (from gupload) (7.0)
# Requirement already satisfied: google-api-python-client==1.7.10 in /usr/local/lib/python3.7/dist-packages (from gupload) (1.7.10)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.7.10->gupload) (0.0.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.7.10->gupload) (3.0.1)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.7.10->gupload) (1.15.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.7.10->gupload) (1.35.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client==1.7.10->gupload) (0.17.4)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->google-api-python-client==1.7.10->gupload) (57.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->google-api-python-client==1.7.10->gupload) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->google-api-python-client==1.7.10->gupload) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->google-api-python-client==1.7.10->gupload) (0.2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->google-api-python-client==1.7.10->gupload) (0.4.8)

# %% [markdown]
# How I currently imagine product model
#
# {
# * 'fdc_id': 1888544,
# * 'description': 'Cookshire toast',
# * 'portion': [
#  * {
#    * 'seq_num': 1,
#    * 'amount': 0.5,
#    * 'modifier': cup
#    * 'gram_weight': 114,
#  * },
#  * {
#    * 'seq_num':2,
#    * 'amount': 0.5,
#    * 'modifier': 'fl oz',
#    * 'gram_weight': 30.2,
#  * }
# * ]
# * 'nutrient': [
#   * {
#     * 'nutrient_id': 1003,
#     * 'nutrient_amount': 5.88,
#   * }
#   * {
#     * 'nutrient_id': 1002,
#     * 'nutrient_amount': 6.33,
#   * }
# * ]
#
# }

# %% [markdown]
# Taking original dataframes and merging them to have a good ground

# %%
merged_portion = pd.merge(sr_data_cleaned, sr_legacy_data_portions, how='inner', on='fdc_id')
merged_portion.drop(columns=['publication_date', 'food_category_id', 'id', 'data_type', 'measure_unit_id', 'portion_description', 'data_points', 'footnote', 'min_year_acquired'], inplace=True)
merged_portion['type'] = 'portion'
merged_portion = merged_portion[['fdc_id', 'description', 'type', 'seq_num', 'amount', 'modifier', 'gram_weight']]
merged_portion.head(5)
len(merged_portion[merged_portion['fdc_id'] == 171687])
# Out:
# 2

# %%
# solution based on https://stackoverflow.com/questions/52923685/convert-pandas-multiindex-series-to-json-python
merged_portion_json = (merged_portion.groupby(['fdc_id','description', 'type'])['seq_num', 'amount', 'modifier', 'gram_weight']
       .apply(lambda x: x.to_dict(orient='records'))
       .reset_index(name='portion')
       #.groupby(['fdc_id', 'description', 'food_category_id', 'type'])['data']
       #.apply(lambda x: x.set_index(['type'])['data'].to_dict('split'))
       #.to_json(orient='records')
       )

#for group, frame in merged_json:
#  print(frame.columns)
#  print(frame)
#print(merged_portion_json[:6000])
merged_portion_json.head(50)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#     fdc_id  ...                                                                                                                                                                                                                                                                                                                    portion
# 0   167512  ...                                                                                                                                                                                                                                                [{'seq_num': 1, 'amount': 1.0, 'modifier': 'serving', 'gram_weight': 34.0}]
# 1   167513  ...                                                                                                                                                                                                                              [{'seq_num': 1, 'amount': 1.0, 'modifier': 'serving 1 roll with icing', 'gram_weight': 44.0}]
# 2   167514  ...                                                                                                                                                                                                                                                [{'seq_num': 1, 'amount': 1.0, 'modifier': 'serving', 'gram_weight': 28.0}]
# 3   167515  ...                                                                                                                                                                                                                                                [{'seq_num': 1, 'amount': 1.0, 'modifier': 'serving', 'gram_weight': 57.0}]
# 4   167516  ...                                                                                                                                                        [{'seq_num': 1, 'amount': 1.0, 'modifier': 'waffle, square', 'gram_weight': 39.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'waffle, round', 'gram_weight': 38.0}]
# 5   167517  ...                                                                                                                                                            [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'waffle round (4" dia)', 'gram_weight': 33.0}]
# 6   167518  ...                                                                                                                                                                                                                                                 [{'seq_num': 1, 'amount': 1.0, 'modifier': 'waffle', 'gram_weight': 35.0}]
# 7   167519  ...                                                                                                                                                                                                                                  [{'seq_num': 1, 'amount': 1.0, 'modifier': 'waffle, round (4"dia)', 'gram_weight': 32.0}]
# 8   167520  ...                                                                                                                                                                          [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'crust', 'gram_weight': 183.0}]
# 9   167521  ...                                                                                                                                                                                                                                                 [{'seq_num': 1, 'amount': 1.0, 'modifier': 'crust', 'gram_weight': 182.0}]
# 10  167522  ...  [{'seq_num': 1, 'amount': 0.12, 'modifier': 'pie 1 pie (1/8 of 9" pie)', 'gram_weight': 131.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'slice', 'gram_weight': 137.0}, {'seq_num': 3, 'amount': 1.0, 'modifier': 'pie', 'gram_weight': 1137.0}, {'seq_num': 4, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}]
# 11  167523  ...                                                                                                                                                                                                                            [{'seq_num': 1, 'amount': 1.0, 'modifier': 'pie crust (average weight)', 'gram_weight': 225.0}]
# 12  167524  ...                                                                                                                                                                                                                                                [{'seq_num': 1, 'amount': 2.0, 'modifier': 'waffles', 'gram_weight': 70.0}]
# 13  167525  ...                                                                                                                          [{'seq_num': 1, 'amount': 1.0, 'modifier': 'piece', 'gram_weight': 12.3}, {'seq_num': 2, 'amount': 3.0, 'modifier': 'pieces (mean serving weight, aggregated over brands)', 'gram_weight': 37.0}]
# 14  167526  ...                                                                                                      [{'seq_num': 1, 'amount': 1.0, 'modifier': 'serving (approximate serving size)', 'gram_weight': 55.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'cake square (average weight of whole item)', 'gram_weight': 399.0}]
# 15  167527  ...                                                                                                                                                                [{'seq_num': 1, 'amount': 1.0, 'modifier': 'serving', 'gram_weight': 55.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'cake square', 'gram_weight': 622.0}]
# 16  167528  ...                                                                                                                                                                                                                                                  [{'seq_num': 1, 'amount': 1.0, 'modifier': 'piece', 'gram_weight': 86.0}]
# 17  167529  ...                                                                                                                                 [{'seq_num': 1, 'amount': 1.0, 'modifier': 'serving (1 NLEA serving - about 4 crackers)', 'gram_weight': 30.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'cracker', 'gram_weight': 12.7}]
# 18  167530  ...                                                                                                                                                   [{'seq_num': 1, 'amount': 11.0, 'modifier': 'crackers (1 NLEA serving)', 'gram_weight': 31.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'cracker', 'gram_weight': 3.1}]
# 19  167531  ...                                                                                                                                                   [{'seq_num': 1, 'amount': 10.0, 'modifier': 'crackers (1 NLEA serving)', 'gram_weight': 32.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'cracker', 'gram_weight': 3.1}]
# 20  167532  ...                                                                                                                                                                                                                                                  [{'seq_num': 1, 'amount': 1.0, 'modifier': 'slice', 'gram_weight': 28.0}]
# 21  167533  ...                                                                                                                                                                                                                                                  [{'seq_num': 1, 'amount': 1.0, 'modifier': 'bagel', 'gram_weight': 98.0}]
# 22  167534  ...                                                                                                                                                                                                                                                    [{'seq_num': 1, 'amount': 4.0, 'modifier': 'oz', 'gram_weight': 113.0}]
# 23  167535  ...                                                                                                                                                                   [{'seq_num': 1, 'amount': 1.0, 'modifier': 'tortilla', 'gram_weight': 49.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'package', 'gram_weight': 484.0}]
# 24  167536  ...                                                                                             [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'piece, large', 'gram_weight': 20.0}, {'seq_num': 3, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}]
# 25  167537  ...                                                                                               [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 3, 'amount': 1.0, 'modifier': 'bag (7 oz)', 'gram_weight': 198.0}]
# 26  167538  ...                                                                                                                                                                     [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'bag (7 oz)', 'gram_weight': 198.0}]
# 27  167539  ...                                                                                                                                                                                                                                                    [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}]
# 28  167540  ...                                                                                      [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'package', 'gram_weight': 27.0}, {'seq_num': 3, 'amount': 1.0, 'modifier': 'packet (.75 oz)', 'gram_weight': 21.0}]
# 29  167541  ...                                                                                                                                                                         [{'seq_num': 1, 'amount': 1.0, 'modifier': 'large', 'gram_weight': 21.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'small', 'gram_weight': 14.0}]
# 30  167542  ...                                                                                               [{'seq_num': 1, 'amount': 1.0, 'modifier': 'bar', 'gram_weight': 21.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'bar (1 oz)', 'gram_weight': 28.0}, {'seq_num': 3, 'amount': 1.0, 'modifier': 'bar', 'gram_weight': 25.0}]
# 31  167543  ...                                                                                                                                                                             [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'bar', 'gram_weight': 24.0}]
# 32  167544  ...                                                                                                                                                             [{'seq_num': 1, 'amount': 1.0, 'modifier': 'bar (1.5 oz)', 'gram_weight': 43.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'bar (1 oz)', 'gram_weight': 28.0}]
# 33  167545  ...                                                                                                                                                            [{'seq_num': 1, 'amount': 1.0, 'modifier': 'bar (1.25 oz)', 'gram_weight': 35.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'bar (1 oz)', 'gram_weight': 28.0}]
# 34  167546  ...                                                                                                                                                                                                                                                [{'seq_num': 1, 'amount': 1.0, 'modifier': 'serving', 'gram_weight': 40.0}]
# 35  167547  ...                                                                                                                                                                             [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'bar', 'gram_weight': 37.0}]
# 36  167548  ...                                                                                                                                                                                                                                             [{'seq_num': 1, 'amount': 1.0, 'modifier': 'bar (1 oz)', 'gram_weight': 28.0}]
# 37  167549  ...                                                                                                                                                                             [{'seq_num': 1, 'amount': 1.0, 'modifier': 'cup', 'gram_weight': 11.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}]
# 38  167550  ...                                                                                                                                                                          [{'seq_num': 1, 'amount': 1.0, 'modifier': 'cake', 'gram_weight': 10.0}, {'seq_num': 2, 'amount': 2.0, 'modifier': 'cakes', 'gram_weight': 20.0}]
# 39  167551  ...                                                                                                                                                             [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz (approx 2/3 cup)', 'gram_weight': 28.35}, {'seq_num': 2, 'amount': 2.0, 'modifier': 'oz', 'gram_weight': 57.0}]
# 40  167552  ...                                                                                                                                                                                                                                                    [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}]
# 41  167553  ...                                                                                                                                                                     [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'can (6 oz)', 'gram_weight': 170.0}]
# 42  167554  ...                                                                                                                                                                  [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'can (6.75 oz)', 'gram_weight': 198.0}]
# 43  167555  ...                                                                                                                                                                         [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 2, 'amount': 10.0, 'modifier': 'twists', 'gram_weight': 60.0}]
# 44  167556  ...                                                                                                                                                                         [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'pretzel', 'gram_weight': 11.0}]
# 45  167557  ...                                                                                                                                                                           [{'seq_num': 1, 'amount': 1.0, 'modifier': 'cake', 'gram_weight': 9.0}, {'seq_num': 2, 'amount': 2.0, 'modifier': 'cakes', 'gram_weight': 18.0}]
# 46  167558  ...                                                                                                                                                                            [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'bag', 'gram_weight': 213.0}]
# 47  167559  ...                                                                                                                                                                                                                                                    [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}]
# 48  167560  ...                                                                                                                                                                     [{'seq_num': 1, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'bag (7 oz)', 'gram_weight': 198.0}]
# 49  167561  ...                                                                                                      [{'seq_num': 1, 'amount': 1.0, 'modifier': 'cup', 'gram_weight': 150.0}, {'seq_num': 2, 'amount': 1.0, 'modifier': 'oz', 'gram_weight': 28.35}, {'seq_num': 3, 'amount': 1.5, 'modifier': 'oz', 'gram_weight': 42.0}]
#
# [50 rows x 4 columns]

# %% [markdown]
# # PnL and Tax experiment

# %% [markdown]
# Experimenting to find out good way of formatting Dataframes

# %%
pnl = pd.DataFrame(index=['Company A', 'Company B', 'Company B'], columns=['Product Name', 'Price'], data={'Product Name':['Orange', 'Apple', 'Grapes'],'Price':['3000', '2000', '1000']})
pnl
# Out:
#           Product Name Price
# Company A       Orange  3000
# Company B        Apple  2000
# Company B       Grapes  1000

# %%
tax = pd.DataFrame(index=['Company A', 'Company B', 'Company B'], columns=['Product Name', 'Price'], data={'Product Name':['Orange', 'Apple', 'Grapes'],'Price':['100', '100', '10']})
tax
# Out:
#           Product Name Price
# Company A       Orange   100
# Company B        Apple   100
# Company B       Grapes    10

# %%
df1 = pd.concat([pnl, tax], keys=('PnL','Tax')).reset_index()
df1.columns = ['type','company','productName','price']
print (df1)
# Out:
#   type    company productName price
# 0  PnL  Company A      Orange  3000
# 1  PnL  Company B       Apple  2000
# 2  PnL  Company B      Grapes  1000
# 3  Tax  Company A      Orange   100
# 4  Tax  Company B       Apple   100
# 5  Tax  Company B      Grapes    10

# %%
d = (df1.groupby(['type','company'])['productName','price']
       .apply(lambda x: x.to_dict('r'))
       .reset_index(name='data')
       .groupby('type')['company','data']
       .apply(lambda x: x.set_index('company')['data'].to_dict())
       .to_json()
       )

print(d[:1000])

#for group, frame in d:
#  print(frame)
# Out:
# {"PnL":{"Company A":[{"productName":"Orange","price":"3000"}],"Company B":[{"productName":"Apple","price":"2000"},{"productName":"Grapes","price":"1000"}]},"Tax":{"Company A":[{"productName":"Orange","price":"100"}],"Company B":[{"productName":"Apple","price":"100"},{"productName":"Grapes","price":"10"}]}}
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:1490: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   after removing the cwd from sys.path.

# %% [markdown]
# # Introducing food_nutrient to our DB

# %%
df_nutrients = sr_legacy_data_nutrients.copy()
df_nutrients.drop(columns=['id', 'min', 'max', 'median', 'derivation_id', 'data_points', 'footnote', 'min_year_acquired'], inplace=True)
df_nutrients.rename(columns={'amount': 'nutrient_amount'}, inplace=True)
len(df_nutrients[df_nutrients['fdc_id'] == 171687])
# Out:
# 68

# %% [markdown]
# # getting description and food_category_id and type into nutrients df

# %% [markdown]
# In cell below there is an error. It seems that each portion has it's own amount of nutrients, which is not correct according to the documentation created couple of cells higher. Resolve tomorrow

# %%
nutrient = pd.merge(df_nutrients,merged_portion_json[['fdc_id', 'description']], how='left', on='fdc_id')
nutrient = nutrient[['fdc_id','description' , 'nutrient_id', 'nutrient_amount']]
#nutrient.head(50)
nutrient[nutrient['description'] == 'Acerola juice, raw']
# Out:
#         fdc_id         description  nutrient_id  nutrient_amount
# 347554  171687  Acerola juice, raw         1062           96.000
# 347555  171687  Acerola juice, raw         1186            0.000
# 347556  171687  Acerola juice, raw         1259            0.000
# 347557  171687  Acerola juice, raw         1260            0.000
# 347558  171687  Acerola juice, raw         1262            0.000
# 347559  171687  Acerola juice, raw         1265            0.048
# 347560  171687  Acerola juice, raw         1266            0.016
# 347561  171687  Acerola juice, raw         1268            0.081
# 347562  171687  Acerola juice, raw         1269            0.046
# 347563  171687  Acerola juice, raw         1270            0.044
# 347564  171687  Acerola juice, raw         1271            0.000
# 347565  171687  Acerola juice, raw         1276            0.000
# 347566  171687  Acerola juice, raw         1277            0.000
# 347567  171687  Acerola juice, raw         1279            0.000
# 347568  171687  Acerola juice, raw         1292            0.082
# 347569  171687  Acerola juice, raw         1258            0.068
# 347570  171687  Acerola juice, raw         1261            0.000
# 347571  171687  Acerola juice, raw         1263            0.000
# 347572  171687  Acerola juice, raw         1264            0.002
# 347573  171687  Acerola juice, raw         1272            0.000
# 347574  171687  Acerola juice, raw         1275            0.001
# 347575  171687  Acerola juice, raw         1278            0.000
# 347576  171687  Acerola juice, raw         1280            0.000
# 347577  171687  Acerola juice, raw         1106           25.000
# 347578  171687  Acerola juice, raw         1107          305.000
# 347579  171687  Acerola juice, raw         1108            0.000
# 347580  171687  Acerola juice, raw         1120            0.000
# 347581  171687  Acerola juice, raw         1122            0.000
# 347582  171687  Acerola juice, raw         1185            1.400
# 347583  171687  Acerola juice, raw         1187           14.000
# 347584  171687  Acerola juice, raw         1109            0.180
# 347585  171687  Acerola juice, raw         1123           17.000
# 347586  171687  Acerola juice, raw         1190           14.000
# 347587  171687  Acerola juice, raw         1057            0.000
# 347588  171687  Acerola juice, raw         1058            0.000
# 347589  171687  Acerola juice, raw         2000            4.500
# 347590  171687  Acerola juice, raw         1095            0.100
# 347591  171687  Acerola juice, raw         1293            0.090
# 347592  171687  Acerola juice, raw         1177           14.000
# 347593  171687  Acerola juice, raw         1098            0.086
# 347594  171687  Acerola juice, raw         1018            0.000
# 347595  171687  Acerola juice, raw         1008           23.000
# 347596  171687  Acerola juice, raw         1105            0.000
# 347597  171687  Acerola juice, raw         1257            0.000
# 347598  171687  Acerola juice, raw         1003            0.400
# 347599  171687  Acerola juice, raw         1007            0.200
# 347600  171687  Acerola juice, raw         1079            0.300
# 347601  171687  Acerola juice, raw         1089            0.500
# 347602  171687  Acerola juice, raw         1090           12.000
# 347603  171687  Acerola juice, raw         1091            9.000
# 347604  171687  Acerola juice, raw         1093            3.000
# 347605  171687  Acerola juice, raw         1104          509.000
# 347606  171687  Acerola juice, raw         1178            0.000
# 347607  171687  Acerola juice, raw         1162         1600.000
# 347608  171687  Acerola juice, raw         1165            0.020
# 347609  171687  Acerola juice, raw         1166            0.060
# 347610  171687  Acerola juice, raw         1253            0.000
# 347611  171687  Acerola juice, raw         1004            0.300
# 347612  171687  Acerola juice, raw         1005            4.800
# 347613  171687  Acerola juice, raw         1051           94.300
# 347614  171687  Acerola juice, raw         1087           10.000
# 347615  171687  Acerola juice, raw         1092           97.000
# 347616  171687  Acerola juice, raw         1167            0.400
# 347617  171687  Acerola juice, raw         1170            0.205
# 347618  171687  Acerola juice, raw         1175            0.004
# 347619  171687  Acerola juice, raw         1242            0.000
# 347620  171687  Acerola juice, raw         1246            0.000
# 347621  171687  Acerola juice, raw         1103            0.100

# %%
#df_nutrient_descriptions.drop(columns=['nutrient_nbr', 'rank'], inplace=True)

# %%
merged_nutrient_description = pd.merge(nutrient, df_nutrient_descriptions, how='left', left_on='nutrient_id', right_on='id')
#merged_nutrient_description.head()
merged_nutrient_description.drop(columns='id', inplace=True)
merged_nutrient_description_final = merged_nutrient_description[['fdc_id', 'description', 'nutrient_id', 'name', 'nutrient_amount', 'unit_name']].copy()
merged_nutrient_description_final.rename(columns={'name':'nutrient_name', 'unit_name':'nutrient_unit_name'}, inplace=True)
merged_nutrient_description_final
len(merged_nutrient_description_final[merged_nutrient_description_final['description'] == 'Acerola juice, raw'])
# Out:
# 68

# %% [markdown]
# # preprocessing nutrients to a dict

# %%
nutrients_dict = (merged_nutrient_description_final.groupby(['fdc_id', 'description'])['nutrient_id', 'nutrient_name', 'nutrient_amount', 'nutrient_unit_name']
     .apply(lambda x: x.to_dict(orient='records'))
     .reset_index(name='nutrient')
     #.to_json(orient='records')
)

#d[:6000]
#merged_json['fdc_id'].index
#series.compare(merged_json['fdc_id'].sort_values())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # putting all data together into one df

# %%
#concatenated_nutrients = pd.concat([merged_portion, nutrient])
#concatenated_nutrients.sort_values(by='fdc_id', inplace=True)
#print(concatenated_nutrients.columns)

merged_portion_nutrient = pd.merge(nutrients_dict, merged_portion_json, how='right', on=['fdc_id', 'description'])
merged_portion_nutrient.drop(columns='type',inplace=True)
merged_portion_nutrient = merged_portion_nutrient[['fdc_id', 'description', 'portion','nutrient']]

#to json file
res = merged_portion_nutrient.to_json('ingredients.json', orient='records')

#print here
res = merged_portion_nutrient.to_json(orient='records')
print(res[:20000])
# Out:
# [{"fdc_id":167512,"description":"Pillsbury Golden Layer Buttermilk Biscuits, Artificial Flavor, refrigerated dough","portion":[{"seq_num":1,"amount":1.0,"modifier":"serving","gram_weight":34.0}],"nutrient":[{"nutrient_id":1003,"nutrient_name":"Protein","nutrient_amount":5.88,"nutrient_unit_name":"G"},{"nutrient_id":1007,"nutrient_name":"Ash","nutrient_amount":3.5,"nutrient_unit_name":"G"},{"nutrient_id":1062,"nutrient_name":"Energy","nutrient_amount":1286.0,"nutrient_unit_name":"kJ"},{"nutrient_id":1079,"nutrient_name":"Fiber, total dietary","nutrient_amount":1.2,"nutrient_unit_name":"G"},{"nutrient_id":1089,"nutrient_name":"Iron, Fe","nutrient_amount":2.12,"nutrient_unit_name":"MG"},{"nutrient_id":1093,"nutrient_name":"Sodium, Na","nutrient_amount":1059.0,"nutrient_unit_name":"MG"},{"nutrient_id":1253,"nutrient_name":"Cholesterol","nutrient_amount":0.0,"nutrient_unit_name":"MG"},{"nutrient_id":1257,"nutrient_name":"Fatty acids, total trans","nutrient_amount":4.412,"nutrient_unit_name":"G"},{"nutrient_id":1258,"nutrient_name":"Fatty acids, total saturated","nutrient_amount":2.941,"nutrient_unit_name":"G"},{"nutrient_id":1004,"nutrient_name":"Total lipid (fat)","nutrient_amount":13.24,"nutrient_unit_name":"G"},{"nutrient_id":1005,"nutrient_name":"Carbohydrate, by difference","nutrient_amount":41.18,"nutrient_unit_name":"G"},{"nutrient_id":1008,"nutrient_name":"Energy","nutrient_amount":307.0,"nutrient_unit_name":"KCAL"},{"nutrient_id":1051,"nutrient_name":"Water","nutrient_amount":35.5,"nutrient_unit_name":"G"},{"nutrient_id":2000,"nutrient_name":"Sugars, total including NLEA","nutrient_amount":5.88,"nutrient_unit_name":"G"}]},{"fdc_id":167513,"description":"Pillsbury, Cinnamon Rolls with Icing, refrigerated dough","portion":[{"seq_num":1,"amount":1.0,"modifier":"serving 1 roll with icing","gram_weight":44.0}],"nutrient":[{"nutrient_id":1003,"nutrient_name":"Protein","nutrient_amount":4.34,"nutrient_unit_name":"G"},{"nutrient_id":1007,"nutrient_name":"Ash","nutrient_amount":3.08,"nutrient_unit_name":"G"},{"nutrient_id":1062,"nutrient_name":"Energy","nutrient_amount":1381.0,"nutrient_unit_name":"kJ"},{"nutrient_id":1079,"nutrient_name":"Fiber, total dietary","nutrient_amount":1.4,"nutrient_unit_name":"G"},{"nutrient_id":1089,"nutrient_name":"Iron, Fe","nutrient_amount":1.93,"nutrient_unit_name":"MG"},{"nutrient_id":1093,"nutrient_name":"Sodium, Na","nutrient_amount":780.0,"nutrient_unit_name":"MG"},{"nutrient_id":1104,"nutrient_name":"Vitamin A, IU","nutrient_amount":1.0,"nutrient_unit_name":"IU"},{"nutrient_id":1106,"nutrient_name":"Vitamin A, RAE","nutrient_amount":0.0,"nutrient_unit_name":"UG"},{"nutrient_id":1162,"nutrient_name":"Vitamin C, total ascorbic acid","nutrient_amount":0.1,"nutrient_unit_name":"MG"},{"nutrient_id":1253,"nutrient_name":"Cholesterol","nutrient_amount":0.0,"nutrient_unit_name":"MG"},{"nutrient_id":1257,"nutrient_name":"Fatty acids, total trans","nutrient_amount":4.29,"nutrient_unit_name":"G"},{"nutrient_id":1258,"nutrient_name":"Fatty acids, total saturated","nutrient_amount":3.25,"nutrient_unit_name":"G"},{"nutrient_id":1004,"nutrient_name":"Total lipid (fat)","nutrient_amount":11.27,"nutrient_unit_name":"G"},{"nutrient_id":1005,"nutrient_name":"Carbohydrate, by difference","nutrient_amount":53.42,"nutrient_unit_name":"G"},{"nutrient_id":1008,"nutrient_name":"Energy","nutrient_amount":330.0,"nutrient_unit_name":"KCAL"},{"nutrient_id":1051,"nutrient_name":"Water","nutrient_amount":27.86,"nutrient_unit_name":"G"},{"nutrient_id":2000,"nutrient_name":"Sugars, total including NLEA","nutrient_amount":21.34,"nutrient_unit_name":"G"},{"nutrient_id":1087,"nutrient_name":"Calcium, Ca","nutrient_amount":28.0,"nutrient_unit_name":"MG"}]},{"fdc_id":167514,"description":"Kraft Foods, Shake N Bake Original Recipe, Coating for Pork, dry","portion":[{"seq_num":1,"amount":1.0,"modifier":"serving","gram_weight":28.0}],"nutrient":[{"nutrient_id":1062,"nutrient_name":"Energy","nutrient_amount":1577.0,"nutrient_unit_name" ...

# %% [markdown]
# # exporting to json file

# %%
# !gupload --to '1sSrmiwT6GX3EylUouR_lakdR3x1qX1xi' ingredients.json
# Out:
# Uploading file: ingredients.json

# %% [markdown]
# # Product search demo

# %%
#merged_portion_nutrient[merged_portion_nutrient['description'].str.contains('wheat flour',case=False)]
pd.set_option('display.max_colwidth', None)
dfp = merged_portion_nutrient[merged_portion_nutrient['fdc_id'] == 167705]
dfp['nutrient'].to_csv('167705.csv')

# %%
# !gupload --to '1sSrmiwT6GX3EylUouR_lakdR3x1qX1xi' '167705.csv'
# Out:
# Uploading file: 167705.csv
